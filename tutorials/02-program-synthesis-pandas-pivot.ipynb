# %% [markdown]
# # Building a Synthesizer for Pivot
#
# In this tutorial, we will build a simple but efficient synthesizer for the Pandas [pivot](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.pivot.html) function. More concretely, given an input dataframe and a desired output dataframe, our synthesizer will output the arguments that need to be passed to pivot that can reproduce the desired output.

# %% [markdown]
# ## Arguments Generator for Pivot
# First let us define a generator that will be our synthesis engine for pivot. As mentioned earlier, this generator will enumerate possible argument combinations. Here is one version which simply selects one of the columns for each of the arguments (or the default value of `None`).

# %%
from atlas import generator

@generator
def pivot_args_generator(input_df):
    arg_columns = Select([None] + list(input_df.columns))
    arg_index = Select([None] + list(input_df.columns))
    arg_values = Select([None] + list(input_df.columns))
    
    return {'index': arg_index, 'columns': arg_columns, 'values': arg_values}

# %% [markdown]
# Now let's try running it on a sample dataframe

# %%
import pandas as pd
df = pd.DataFrame({
  'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
  'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
  'baz': [10, 20, 30, 40, 50, 60],
})
df
# Out:
#    foo bar  baz
# 0  one   A   10
# 1  one   B   20
# 2  one   C   30
# 3  two   A   40
# 4  two   B   50
# 5  two   C   60

# %%
for args in pivot_args_generator.generate(df):
    print(args)
# Out:
# {'index': None, 'columns': None, 'values': None}
# {'index': None, 'columns': None, 'values': 'foo'}
# {'index': None, 'columns': None, 'values': 'bar'}
# {'index': None, 'columns': None, 'values': 'baz'}
# {'index': 'foo', 'columns': None, 'values': None}
# {'index': 'foo', 'columns': None, 'values': 'foo'}
# {'index': 'foo', 'columns': None, 'values': 'bar'}
# {'index': 'foo', 'columns': None, 'values': 'baz'}
# {'index': 'bar', 'columns': None, 'values': None}
# {'index': 'bar', 'columns': None, 'values': 'foo'}
# {'index': 'bar', 'columns': None, 'values': 'bar'}
# {'index': 'bar', 'columns': None, 'values': 'baz'}
# {'index': 'baz', 'columns': None, 'values': None}
# {'index': 'baz', 'columns': None, 'values': 'foo'}
# {'index': 'baz', 'columns': None, 'values': 'bar'}
# {'index': 'baz', 'columns': None, 'values': 'baz'}
# {'index': None, 'columns': 'foo', 'values': None}
# {'index': None, 'columns': 'foo', 'values': 'foo'}
# {'index': None, 'columns': 'foo', 'values': 'bar'}
# {'index': None, 'columns': 'foo', 'values': 'baz'}
# {'index': 'foo', 'columns': 'foo', 'values': None}
# {'index': 'foo', 'columns': 'foo', 'values': 'foo'}
# {'index': 'foo', 'columns': 'foo', 'values': 'bar'}
# {'index': 'foo', 'columns': 'foo', 'values': 'baz'}
# {'index': 'bar', 'columns': 'foo', 'values': None}
# {'index': 'bar', 'columns': 'foo', 'values': 'foo'}
# {'index': 'bar', 'columns': 'foo', 'values': 'bar'}
# {'index': 'bar', 'columns': 'foo', 'values': 'baz'}
# {'index': 'baz', 'columns': 'foo', 'values': None}
# {'index': 'baz', 'columns': 'foo', 'values': 'foo'}
# {'index': 'baz', 'columns': 'foo', 'values': 'bar'}
# {'index': 'baz', 'columns': 'foo', 'values': 'baz'}
# {'index': None, 'columns': 'bar', 'values': None}
# {'index': None, 'columns': 'bar', 'values': 'foo'}
# {'index': None, 'columns': 'bar', 'values': 'bar'}
# {'index': None, 'columns': 'bar', 'values': 'baz'}
# {'index': 'foo', 'columns': 'bar', 'values': None}
# {'index': 'foo', 'columns': 'bar', 'values': 'foo'}
# {'index': 'foo', 'columns': 'bar', 'values': 'bar'}
# {'index': 'foo', 'columns': 'bar', 'values': 'baz'}
# {'index': 'bar', 'columns': 'bar', 'values': None}
# {'index': 'bar', 'columns': 'bar', 'values': 'foo'}
# {'index': 'bar', 'columns': 'bar', 'values': 'bar'}
# {'index': 'bar', 'columns': 'bar', 'values': 'baz'}
# {'index': 'baz', 'columns': 'bar', 'values': None}
# {'index': 'baz', 'columns': 'bar', 'values': 'foo'}
# {'index': 'baz', 'columns': 'bar', 'values': 'bar'}
# {'index': 'baz', 'columns': 'bar', 'values': 'baz'}
# {'index': None, 'columns': 'baz', 'values': None}
# {'index': None, 'columns': 'baz', 'values': 'foo'}
# {'index': None, 'columns': 'baz', 'values': 'bar'}
# {'index': None, 'columns': 'baz', 'values': 'baz'}
# {'index': 'foo', 'columns': 'baz', 'values': None}
# {'index': 'foo', 'columns': 'baz', 'values': 'foo'}
# {'index': 'foo', 'columns': 'baz', 'values': 'bar'}
# {'index': 'foo', 'columns': 'baz', 'values': 'baz'}
# {'index': 'bar', 'columns': 'baz', 'values': None}
# {'index': 'bar', 'columns': 'baz', 'values': 'foo'}
# {'index': 'bar', 'columns': 'baz', 'values': 'bar'}
# {'index': 'bar', 'columns': 'baz', 'values': 'baz'}
# {'index': 'baz', 'columns': 'baz', 'values': None}
# {'index': 'baz', 'columns': 'baz', 'values': 'foo'}
# {'index': 'baz', 'columns': 'baz', 'values': 'bar'}
# {'index': 'baz', 'columns': 'baz', 'values': 'baz'}

# %% [markdown]
# However, not all the argument combinations printed above are valid. Not convinced? Let's try executing them.

# %%
for args in pivot_args_generator.generate(df):
    print(args, df.pivot(**args))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-bf6bc726e3d4> in <module>()
#       1 for args in pivot_args_generator.generate(df):
# ----> 2     print(args, df.pivot(**args))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     398         cols = [columns] if index is None else [index, columns]
#     399         append = index is None
# --> 400         indexed = self.set_index(cols, append=append)
#     401     else:
#     402         if index is None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4122                         loc = indexer.item()
#    4123                     else:
# -> 4124                         raise ValueError("cannot label index with a null key")
#    4125
#    4126             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key

# %% [markdown]
# Pandas threw an error as our generator is not *precise* while enumerating arguments. That is, it generates argument combinations which cause the pandas pivot function to throw an error. There are a number of hard-to-see constraints embedded in the [documentation](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.pivot.html) for pivot. For example, the columns argument is not marked *Optional* even though it is a keyword argument. We have already done the job of incorporating all these constraints in the generator below.

# %%
@generator
def pivot_args_generator(input_df): 
    def dup_filter(cand):
        try:
            return not any(input_df[[cand, arg_columns]].duplicated())
        except:
            return True

    arg_columns = Select(input_df.columns)
    arg_index = Select([None] + list(filter(dup_filter, set(input_df.columns) - {arg_columns})))

    if input_df.index.nlevels > 1 and arg_index is None:
        arg_values = None
    else:
        arg_values = Select(set(input_df.columns) | {None})

    return {'columns': arg_columns, 'index': arg_index, 'values': arg_values}

# %%
for args in pivot_args_generator.generate(df):
    print(args)
# Out:
# {'columns': 'foo', 'index': None, 'values': 'baz'}
# {'columns': 'foo', 'index': None, 'values': 'bar'}
# {'columns': 'foo', 'index': None, 'values': 'foo'}
# {'columns': 'foo', 'index': None, 'values': None}
# {'columns': 'foo', 'index': 'baz', 'values': 'baz'}
# {'columns': 'foo', 'index': 'baz', 'values': 'bar'}
# {'columns': 'foo', 'index': 'baz', 'values': 'foo'}
# {'columns': 'foo', 'index': 'baz', 'values': None}
# {'columns': 'foo', 'index': 'bar', 'values': 'baz'}
# {'columns': 'foo', 'index': 'bar', 'values': 'bar'}
# {'columns': 'foo', 'index': 'bar', 'values': 'foo'}
# {'columns': 'foo', 'index': 'bar', 'values': None}
# {'columns': 'bar', 'index': None, 'values': 'baz'}
# {'columns': 'bar', 'index': None, 'values': 'bar'}
# {'columns': 'bar', 'index': None, 'values': 'foo'}
# {'columns': 'bar', 'index': None, 'values': None}
# {'columns': 'bar', 'index': 'baz', 'values': 'baz'}
# {'columns': 'bar', 'index': 'baz', 'values': 'bar'}
# {'columns': 'bar', 'index': 'baz', 'values': 'foo'}
# {'columns': 'bar', 'index': 'baz', 'values': None}
# {'columns': 'bar', 'index': 'foo', 'values': 'baz'}
# {'columns': 'bar', 'index': 'foo', 'values': 'bar'}
# {'columns': 'bar', 'index': 'foo', 'values': 'foo'}
# {'columns': 'bar', 'index': 'foo', 'values': None}
# {'columns': 'baz', 'index': None, 'values': 'baz'}
# {'columns': 'baz', 'index': None, 'values': 'bar'}
# {'columns': 'baz', 'index': None, 'values': 'foo'}
# {'columns': 'baz', 'index': None, 'values': None}
# {'columns': 'baz', 'index': 'bar', 'values': 'baz'}
# {'columns': 'baz', 'index': 'bar', 'values': 'bar'}
# {'columns': 'baz', 'index': 'bar', 'values': 'foo'}
# {'columns': 'baz', 'index': 'bar', 'values': None}
# {'columns': 'baz', 'index': 'foo', 'values': 'baz'}
# {'columns': 'baz', 'index': 'foo', 'values': 'bar'}
# {'columns': 'baz', 'index': 'foo', 'values': 'foo'}
# {'columns': 'baz', 'index': 'foo', 'values': None}

# %% [markdown]
# ## Building a Brute-Force Synthesizer
# Given `pivot_args_generator` we are now ready to build our first brute-force synthesizer for pivot. Given an input-output pair, we will simply enumerate and execute all argument combinations till we find the right one.

# %%
from atlas.synthesis.pandas.checker import Checker
def synthesize(input_df, output_df):
    for args in pivot_args_generator.generate(input_df):
        print("Trying Combination:", args)
        result = input_df.pivot(**args)
        if Checker.check(result, output_df):
            print("Solution Found:", args)
            break

# %% [markdown]
# Try it out!

# %%
desired_output = pd.DataFrame({'one': {'A': 10, 'B': 20, 'C': 30}, 'two': {'A': 40, 'B': 50, 'C': 60}})
desired_output
# Out:
#    one  two
# A   10   40
# B   20   50
# C   30   60

# %%
synthesize(df, desired_output)
# Out:
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'baz'}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'bar'}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'foo'}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': None}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'baz'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'bar'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'foo'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': None}
# Trying Combination: {'columns': 'foo', 'index': 'bar', 'values': 'baz'}
# Solution Found: {'columns': 'foo', 'index': 'bar', 'values': 'baz'}

# %% [markdown]
# ## Building a Smart Synthesizer
# Our brute-force synthesizer works pretty well, but there's still a lot that can be done. First, notice the number of argument combinations explored before arriving at the solution. For large dataframes the synthesis process may be slow. Second, the generator is not *predictive*. It does not tell us what it thinks are the most promising argument combinations. Rather it just goes over the space of values deterministically.
#
# Let us try to *train* the generator to return argument combinations that are *more likely* to be correct for a given input-output dataframe pair.

# %% [markdown]
# ### Adding Output to the Generator
# You may have noticed that the output dataframe is not visible to the argument generator. In order to build a smarter generator, we need to give it access to the output.

# %%
@generator
def pivot_args_generator(input_df, output_df):
    pass

# %% [markdown]
# ### Adding Context to the Generator
# We will pass a **context** to each of the Select operators that will help them make the the right choices by conditioning on this context. Can you guess what the context will be? That's right, it will simply be the input-output example.

# %%
@generator
def pivot_args_generator(input_df, output_df): 
    def dup_filter(cand):
        try:
            return not any(input_df[[cand, arg_columns]].duplicated())
        except:
            return True

    c = {'Input': input_df, 'Output': output_df}
    arg_columns = Select(input_df.columns, context=c)
    arg_index = Select([None] + list(filter(dup_filter, set(input_df.columns) - {arg_columns})), context=c)

    if input_df.index.nlevels > 1 and arg_index is None:
        arg_values = None
    else:
        arg_values = Select(set(input_df.columns) | {None}, context=c)

    return {'columns': arg_columns, 'index': arg_index, 'values': arg_values}

# %% [markdown]
# Need to modify the `synthesize` procedure a bit as well to sync with the above changes

# %%
def synthesize(input_df, output_df):
    for args in pivot_args_generator.generate(input_df, output_df):
        print("Trying Combination:", args)
        result = input_df.pivot(**args)
        if Checker.check(result, output_df):
            print("Solution Found:", args)
            break

# %% [markdown]
# ## Training the Generator
#
# ### Defining the Model
# We need to define the predictive models that the generator will use to refine its output. In particular, we need to define the models used by the Select operators.
#
# Our overall generator model uses a single Tensorflow Graph-Neural-Network architecture for all the Select operators.
#
# *TODO : Construct graph encoding inside the notebook, and use a PyTorch model using PyTorch Geometric*

# %%
from typing import Mapping, Any, Collection
from atlas.tracing import OpTrace
from atlas.models.imitation import IndependentOperatorsModel
from atlas.models.tensorflow.graphs.operators import SelectGGNN
from atlas.synthesis.pandas.encoders import PandasGraphEncoder

class PivotGeneratorModel(IndependentOperatorsModel):
    def Select(*args, **kwargs):
        config = {
            'learning_rate': 0.01,
            'node_dimension': 50,
            'classifier_hidden_dims': [50],
            'batch_size': 30000,
            'layer_timesteps': [1, 1, 1]
        }
        
        return PivotSelectModel(config)
    
class PivotSelectModel(SelectGGNN):
    def __init__(self, params: Mapping[str, Any]):
        self.encoder = PandasGraphEncoder()
        params.update({
            'num_node_features': self.encoder.get_num_node_features(),
            'num_edge_types': self.encoder.get_num_edge_types()
        })
        
        super().__init__(params)
        
    def train(self, training_data: Collection[OpTrace], validation_data: Collection[OpTrace], *args, **kwargs):
        encoded_train = [self.encoder.Select(domain=op.domain, 
                                             context=op.context, 
                                             choice=op.choice, 
                                             sid=op.op_info.sid) for op in training_data]
        encoded_valid = [self.encoder.Select(domain=op.domain, 
                                             context=op.context, 
                                             choice=op.choice, 
                                             sid=op.op_info.sid) for op in validation_data]
        super().train(encoded_train, encoded_valid, *args, **kwargs)
        
    def infer(self, domain, context: Any = None, sid: str = '', **kwargs):
        encoding = self.encoder.Select(domain, context, mode='inference', sid=sid)
        inference = super().infer([encoding])[0]
        return [val for val, prob in sorted(inference, key=lambda x: -x[1])]

# %% [markdown]
# ### Gather Training Data
# To gather training data, we will simply take three dataframes, enumerate all possible argument combinations, execute them and collect the output. We will enable tracing to keep track of the operator choices made. We will then retroactively modify the trace to incorporate the resulting output in the context.
#
# *TODO : This needs a lot of improvement*

# %%
dataframes = [
    pd.DataFrame({
        'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
        'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
        'baz': [10, 20, 30, 40, 50, 60],
    }),

    pd.DataFrame({
        'date': ['1959-03-31 00:00:00'] * 3 + ['1959-06-30 00:00:00'] * 3 + [
            '1959-09-30 00:00:00'] * 3 + ['1959-12-31 00:00:00'],
        'item': ['realgdp', 'infl', 'unemp', 'realgdp', 'infl', 'unemp', 'realgdp', 'infl',
                 'unemp', 'realgdp'],
        'value': [2710.349, 0.001, 5.800, 2778.801, 2.340, 5.100, 2775.488, 2.740, 5.300,
                  2785.204],
    }),

    pd.DataFrame({
        'Date': ['2018-02-18', '2018-02-24', '2018-02-24', '2018-03-01', '2018-03-11', '2018-03-11'],
        'Category': ['Social', 'Lunch', 'Social', 'Lunch', 'Lunch', 'Brunch'],
        'Location': ['Terrace', "Pox", "Gate 320", "Pox", "Cola 543", "Terrace"],
        'Expense': [98.34, 245.63, 121.89, 248.00, 240.40, 561.48],
        'Balance': [9971.66, 9726.03, 9604.14, 9356.04, 9115.74, 8554.26]
    })
]

# %%
traces = []
test_cases = []
for df in dataframes[:3]:
    for args, trace in pivot_args_generator.trace(df, None):
        output = df.pivot(**args)
        for op in trace.op_traces:
            if op.context is not None:
                op.context['Output'] = output

        traces.append(trace)
        test_cases.append((df, output))

# %% [markdown]
# ### Train the Model
# Let us start training the model

# %%
model = PivotGeneratorModel()
model.train(traces, traces, num_epochs=-1)
# Out:
# 100%|██████████| 210/210 [00:00<00:00, 1234.66it/s]
# 100%|██████████| 210/210 [00:00<00:00, 1612.79it/s]
# [+] Training model for /pivot_args_generator/Select@@1
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:317: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# [Training(1/-1)] Loss:  1.431255 Accuracy:  0.3238
# [Validation(1/-1)] Loss:  1.412956 Accuracy:  0.3286
# [Training(2/-1)] Loss:  1.412933 Accuracy:  0.3286
# [Validation(2/-1)] Loss:  1.373981 Accuracy:  0.3286
# [Training(3/-1)] Loss:  1.372369 Accuracy:  0.3619
# [Validation(3/-1)] Loss:  1.311350 Accuracy:  0.3286
# [Training(4/-1)] Loss:  1.309719 Accuracy:  0.3286
# [Validation(4/-1)] Loss:  1.271086 Accuracy:  0.3286
# [Training(5/-1)] Loss:  1.271315 Accuracy:  0.3286
# [Validation(5/-1)] Loss:  1.262286 Accuracy:  0.3286
# [Training(6/-1)] Loss:  1.262206 Accuracy:  0.3286
# [Validation(6/-1)] Loss:  1.261586 Accuracy:  0.3286
# [Training(7/-1)] Loss:  1.261533 Accuracy:  0.3286
# [Validation(7/-1)] Loss:  1.261356 Accuracy:  0.3286
# [Training(8/-1)] Loss:  1.261233 Accuracy:  0.3333
# [Validation(8/-1)] Loss:  1.261291 Accuracy:  0.3286
# [Training(9/-1)] Loss:  1.261212 Accuracy:  0.3286
# [Validation(9/-1)] Loss:  1.261441 Accuracy:  0.3286
# [Training(10/-1)] Loss:  1.261335 Accuracy:  0.3286
# [Validation(10/-1)] Loss:  1.261362 Accuracy:  0.3333
# [Training(11/-1)] Loss:  1.261523 Accuracy:  0.3286
# [Validation(11/-1)] Loss:  1.261282 Accuracy:  0.4143
# [Training(12/-1)] Loss:  1.261289 Accuracy:  0.4190
# [Validation(12/-1)] Loss:  1.260964 Accuracy:  0.3524
# [Training(13/-1)] Loss:  1.260868 Accuracy:  0.3619
# [Validation(13/-1)] Loss:  1.260147 Accuracy:  0.3333
# [Training(14/-1)] Loss:  1.260042 Accuracy:  0.4476
# [Validation(14/-1)] Loss:  1.258689 Accuracy:  0.3476
# [Training(15/-1)] Loss:  1.258806 Accuracy:  0.4571
# [Validation(15/-1)] Loss:  1.254795 Accuracy:  0.3810
# [Training(16/-1)] Loss:  1.255321 Accuracy:  0.3619
# [Validation(16/-1)] Loss:  1.244757 Accuracy:  0.3905
# [Training(17/-1)] Loss:  1.245505 Accuracy:  0.4190
# [Validation(17/-1)] Loss:  1.220388 Accuracy:  0.3952
# [Training(18/-1)] Loss:  1.219369 Accuracy:  0.3810
# [Validation(18/-1)] Loss:  1.167351 Accuracy:  0.4190
# [Training(19/-1)] Loss:  1.166592 Accuracy:  0.4143
# [Validation(19/-1)] Loss:  1.073275 Accuracy:  0.4381
# [Training(20/-1)] Loss:  1.068956 Accuracy:  0.4238
# [Validation(20/-1)] Loss:  0.948264 Accuracy:  0.4857
# [Training(21/-1)] Loss:  0.952752 Accuracy:  0.4857
# [Validation(21/-1)] Loss:  0.910447 Accuracy:  0.5190
# [Training(22/-1)] Loss:  0.880446 Accuracy:  0.5524
# [Validation(22/-1)] Loss:  0.790588 Accuracy:  0.5333
# [Training(23/-1)] Loss:  0.778746 Accuracy:  0.5381
# [Validation(23/-1)] Loss:  0.718081 Accuracy:  0.6048
# [Training(24/-1)] Loss:  0.706655 Accuracy:  0.6143
# [Validation(24/-1)] Loss:  0.695840 Accuracy:  0.5714
# [Training(25/-1)] Loss:  0.702566 Accuracy:  0.5667
# [Validation(25/-1)] Loss:  0.631252 Accuracy:  0.5810
# [Training(26/-1)] Loss:  0.681552 Accuracy:  0.5667
# [Validation(26/-1)] Loss:  0.547283 Accuracy:  0.7000
# [Training(27/-1)] Loss:  0.586547 Accuracy:  0.6524
# [Validation(27/-1)] Loss:  0.502750 Accuracy:  0.7190
# [Training(28/-1)] Loss:  0.543037 Accuracy:  0.7238
# [Validation(28/-1)] Loss:  0.437802 Accuracy:  0.7524
# [Training(29/-1)] Loss:  0.432452 Accuracy:  0.7762
# [Validation(29/-1)] Loss:  0.291780 Accuracy:  0.8381
# [Training(30/-1)] Loss:  0.263984 Accuracy:  0.8238
# [Validation(30/-1)] Loss:  0.140608 Accuracy:  0.9333
# [Training(31/-1)] Loss:  0.189887 Accuracy:  0.9095
# [Validation(31/-1)] Loss:  0.044649 Accuracy:  0.9762
# [Training(32/-1)] Loss:  0.031210 Accuracy:  0.9762
# [Validation(32/-1)] Loss:  0.001758 Accuracy:  1.0000
# [Training(33/-1)] Loss:  0.001328 Accuracy:  1.0000
# [Validation(33/-1)] Loss:  0.002133 Accuracy:  1.0000
# [Training(34/-1)] Loss:  0.007476 Accuracy:  0.9952
# [Validation(34/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Training(35/-1)] Loss:  0.000001 Accuracy:  1.0000
# [Validation(35/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Training(36/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Validation(36/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Training(37/-1)] Loss:  0.000008 Accuracy:  1.0000
# [Validation(37/-1)] Loss:  0.000129 Accuracy:  1.0000
# [Training(38/-1)] Loss:  0.000151 Accuracy:  1.0000
# [Validation(38/-1)] Loss:  0.036397 Accuracy:  0.9810
# [Training(39/-1)] Loss:  0.014075 Accuracy:  0.9905
# [Validation(39/-1)] Loss:  0.029116 Accuracy:  0.9810
# [Training(40/-1)] Loss:  0.251427 Accuracy:  0.9524
# [Validation(40/-1)] Loss:  0.000169 Accuracy:  1.0000
# [Training(41/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Validation(41/-1)] Loss:  0.000011 Accuracy:  1.0000
# [Training(42/-1)] Loss:  0.000078 Accuracy:  1.0000
# [Validation(42/-1)] Loss:  0.000002 Accuracy:  1.0000
# [Training(43/-1)] Loss:  0.000000 Accuracy:  1.0000
# [Validation(43/-1)] Loss:  0.000001 Accuracy:  1.0000
# [Training(44/-1)] Loss:  0.000020 Accuracy:  1.0000
# [Validation(44/-1)] Loss:  0.000003 Accuracy:  1.0000
# [Training(45/-1)] Loss:  0.000001 Accuracy:  1.0000
# [Validation(45/-1)] Loss:  0.000013 Accuracy:  1.0000
# [Training(46/-1)] Loss:  0.000118 Accuracy:  1.0000
# [Validation(46/-1)] Loss:  0.000048 Accuracy:  1.0000
# [Training(47/-1)] Loss:  0.000426 Accuracy:  1.0000
# [Validation(47/-1)] Loss:  0.000112 Accuracy:  1.0000
# [Training(48/-1)] Loss:  0.000009 Accuracy:  1.0000
# [Validation(48/-1)] Loss:  0.000253 Accuracy:  1.0000
# [Training(49/-1)] Loss:  0.000434 Accuracy:  1.0000
# [Validation(49/-1)] Loss:  0.000466 Accuracy:  1.0000
# [Training(50/-1)] Loss:  0.002269 Accuracy:  1.0000
# [Validation(50/-1)] Loss:  0.000608 Accuracy:  1.0000
# [Training(51/-1)] Loss:  0.001130 Accuracy:  1.0000
# [Validation(51/-1)] Loss:  0.000701 Accuracy:  1.0000
# [Training(52/-1)] Loss:  0.010059 Accuracy:  0.9905
# [Validation(52/-1)] Loss:  0.000612 Accuracy:  1.0000
# [Training(53/-1)] Loss:  0.001018 Accuracy:  1.0000
# [Validation(53/-1)] Loss:  0.000558 Accuracy:  1.0000
# [Training(54/-1)] Loss:  0.000177 Accuracy:  1.0000
# [Validation(54/-1)] Loss:  0.000515 Accuracy:  1.0000
# [Training(55/-1)] Loss:  0.000504 Accuracy:  1.0000
# [Validation(55/-1)] Loss:  0.000466 Accuracy:  1.0000
# [Training(56/-1)] Loss:  0.052668 Accuracy:  0.9619
# [Validation(56/-1)] Loss:  0.000199 Accuracy:  1.0000
# [Training(57/-1)] Loss:  0.004006 Accuracy:  1.0000
# [Validation(57/-1)] Loss:  0.000086 Accuracy:  1.0000
# [Training(58/-1)] Loss:  0.000738 Accuracy:  1.0000
# [Validation(58/-1)] Loss:  0.000055 Accuracy:  1.0000
# [+] Training model for /pivot_args_generator/Select@@2
# [Training(1/-1)] Loss:  1.380446 Accuracy:  0.3000
# [Validation(1/-1)] Loss:  1.367815 Accuracy:  0.4000
# [Training(2/-1)] Loss:  1.367888 Accuracy:  0.3952
# [Validation(2/-1)] Loss:  1.357728 Accuracy:  0.3524
# [Training(3/-1)] Loss:  1.356976 Accuracy:  0.3619
# [Validation(3/-1)] Loss:  1.356723 Accuracy:  0.3524
# [Training(4/-1)] Loss:  1.358323 Accuracy:  0.3524
# [Validation(4/-1)] Loss:  1.348596 Accuracy:  0.3667
# [Training(5/-1)] Loss:  1.348442 Accuracy:  0.3667
# [Validation(5/-1)] Loss:  1.342546 Accuracy:  0.4190
# [Training(6/-1)] Loss:  1.342936 Accuracy:  0.4476
# [Validation(6/-1)] Loss:  1.337698 Accuracy:  0.4143
# [Training(7/-1)] Loss:  1.336193 Accuracy:  0.4143
# [Validation(7/-1)] Loss:  1.332036 Accuracy:  0.4143
# [Training(8/-1)] Loss:  1.331448 Accuracy:  0.4143
# [Validation(8/-1)] Loss:  1.317646 Accuracy:  0.4143
# [Training(9/-1)] Loss:  1.317665 Accuracy:  0.4143
# [Validation(9/-1)] Loss:  1.307138 Accuracy:  0.4143
# [Training(10/-1)] Loss:  1.306885 Accuracy:  0.4143
# [Validation(10/-1)] Loss:  1.295153 Accuracy:  0.4143
# [Training(11/-1)] Loss:  1.299416 Accuracy:  0.4143
# [Validation(11/-1)] Loss:  1.280317 Accuracy:  0.4143
# [Training(12/-1)] Loss:  1.277691 Accuracy:  0.4143
# [Validation(12/-1)] Loss:  1.266931 Accuracy:  0.4095
# [Training(13/-1)] Loss:  1.259371 Accuracy:  0.4143
# [Validation(13/-1)] Loss:  1.240120 Accuracy:  0.4143
# [Training(14/-1)] Loss:  1.235870 Accuracy:  0.4143
# [Validation(14/-1)] Loss:  1.282611 Accuracy:  0.4143
# [Training(15/-1)] Loss:  1.263183 Accuracy:  0.4143
# [Validation(15/-1)] Loss:  1.216718 Accuracy:  0.4143
# [Training(16/-1)] Loss:  1.252775 Accuracy:  0.2571
# [Validation(16/-1)] Loss:  1.227605 Accuracy:  0.4143
# [Training(17/-1)] Loss:  1.256729 Accuracy:  0.4143
# [Validation(17/-1)] Loss:  1.212344 Accuracy:  0.4143
# [Training(18/-1)] Loss:  1.214437 Accuracy:  0.4143
# [Validation(18/-1)] Loss:  1.216636 Accuracy:  0.4143
# [Training(19/-1)] Loss:  1.216775 Accuracy:  0.4143
# [Validation(19/-1)] Loss:  1.207446 Accuracy:  0.4333
# [Training(20/-1)] Loss:  1.210200 Accuracy:  0.4762
# [Validation(20/-1)] Loss:  1.205303 Accuracy:  0.5667
# [Training(21/-1)] Loss:  1.219841 Accuracy:  0.4571
# [Validation(21/-1)] Loss:  1.255205 Accuracy:  0.5714
# [Training(22/-1)] Loss:  1.238010 Accuracy:  0.4810
# [Validation(22/-1)] Loss:  1.223239 Accuracy:  0.5619
# [Training(23/-1)] Loss:  1.308663 Accuracy:  0.5619
# [Validation(23/-1)] Loss:  1.249870 Accuracy:  0.2571
# [Training(24/-1)] Loss:  1.261066 Accuracy:  0.2571
# [Validation(24/-1)] Loss:  1.239257 Accuracy:  0.2571
# [Training(25/-1)] Loss:  1.249189 Accuracy:  0.2571
# [Validation(25/-1)] Loss:  1.192579 Accuracy:  0.6190
# [Training(26/-1)] Loss:  1.193678 Accuracy:  0.6190
# [Validation(26/-1)] Loss:  1.203595 Accuracy:  0.6190
# [Training(27/-1)] Loss:  1.212333 Accuracy:  0.6238
# [Validation(27/-1)] Loss:  1.195808 Accuracy:  0.6429
# [Training(28/-1)] Loss:  1.205903 Accuracy:  0.6333
# [Validation(28/-1)] Loss:  1.166630 Accuracy:  0.6333
# [Training(29/-1)] Loss:  1.176264 Accuracy:  0.6381
# [Validation(29/-1)] Loss:  1.150175 Accuracy:  0.6333
# [Training(30/-1)] Loss:  1.155065 Accuracy:  0.6429
# [Validation(30/-1)] Loss:  1.131029 Accuracy:  0.3381
# [Training(31/-1)] Loss:  1.129241 Accuracy:  0.3381
# [Validation(31/-1)] Loss:  1.055043 Accuracy:  0.6524
# [Training(32/-1)] Loss:  1.077509 Accuracy:  0.3571
# [Validation(32/-1)] Loss:  0.936963 Accuracy:  0.6476
# [Training(33/-1)] Loss:  0.914553 Accuracy:  0.6810
# [Validation(33/-1)] Loss:  0.844358 Accuracy:  0.6286
# [Training(34/-1)] Loss:  0.854871 Accuracy:  0.6429
# [Validation(34/-1)] Loss:  0.709068 Accuracy:  0.6857
# [Training(35/-1)] Loss:  0.706894 Accuracy:  0.6524
# [Validation(35/-1)] Loss:  0.705816 Accuracy:  0.6857
# [Training(36/-1)] Loss:  0.663864 Accuracy:  0.6714
# [Validation(36/-1)] Loss:  0.675863 Accuracy:  0.6762
# [Training(37/-1)] Loss:  0.692439 Accuracy:  0.7048
# [Validation(37/-1)] Loss:  0.853892 Accuracy:  0.7429
# [Training(38/-1)] Loss:  0.882401 Accuracy:  0.7381
# [Validation(38/-1)] Loss:  0.748073 Accuracy:  0.7810
# [Training(39/-1)] Loss:  0.727430 Accuracy:  0.7857
# [Validation(39/-1)] Loss:  0.523147 Accuracy:  0.7905
# [Training(40/-1)] Loss:  0.682795 Accuracy:  0.7143
# [Validation(40/-1)] Loss:  0.485501 Accuracy:  0.8095
# [Training(41/-1)] Loss:  0.494688 Accuracy:  0.8048
# [Validation(41/-1)] Loss:  0.457264 Accuracy:  0.8286
# [Training(42/-1)] Loss:  0.475610 Accuracy:  0.8095
# [Validation(42/-1)] Loss:  0.446534 Accuracy:  0.8381
# [Training(43/-1)] Loss:  0.412704 Accuracy:  0.8667
# [Validation(43/-1)] Loss:  0.433949 Accuracy:  0.8571
# [Training(44/-1)] Loss:  0.471655 Accuracy:  0.8238
# [Validation(44/-1)] Loss:  0.419449 Accuracy:  0.8571
# [Training(45/-1)] Loss:  0.424146 Accuracy:  0.8714
# [Validation(45/-1)] Loss:  0.399065 Accuracy:  0.8476
# [Training(46/-1)] Loss:  0.450262 Accuracy:  0.8238
# [Validation(46/-1)] Loss:  0.371654 Accuracy:  0.8524
# [Training(47/-1)] Loss:  0.380089 Accuracy:  0.8619
# [Validation(47/-1)] Loss:  0.332784 Accuracy:  0.8905
# [Training(48/-1)] Loss:  0.390628 Accuracy:  0.8524
# [Validation(48/-1)] Loss:  0.283280 Accuracy:  0.9048
# [Training(49/-1)] Loss:  0.266580 Accuracy:  0.9476
# [Validation(49/-1)] Loss:  0.241382 Accuracy:  0.9381
# [Training(50/-1)] Loss:  0.234299 Accuracy:  0.9476
# [Validation(50/-1)] Loss:  0.197324 Accuracy:  0.9476
# [Training(51/-1)] Loss:  0.214830 Accuracy:  0.9476
# [Validation(51/-1)] Loss:  0.150307 Accuracy:  0.9476
# [Training(52/-1)] Loss:  0.119970 Accuracy:  0.9524
# [Validation(52/-1)] Loss:  0.106149 Accuracy:  0.9667
# [Training(53/-1)] Loss:  0.105904 Accuracy:  0.9667
# [Validation(53/-1)] Loss:  0.066780 Accuracy:  0.9714
# [Training(54/-1)] Loss:  0.057282 Accuracy:  0.9905
# [Validation(54/-1)] Loss:  0.034345 Accuracy:  0.9905
# [Training(55/-1)] Loss:  0.044679 Accuracy:  0.9905
# [Validation(55/-1)] Loss:  0.013480 Accuracy:  1.0000
# [Training(56/-1)] Loss:  0.014267 Accuracy:  1.0000
# [Validation(56/-1)] Loss:  0.008742 Accuracy:  1.0000
# [Training(57/-1)] Loss:  0.035160 Accuracy:  0.9762
# [Validation(57/-1)] Loss:  0.000790 Accuracy:  1.0000
# [Training(58/-1)] Loss:  0.001299 Accuracy:  1.0000
# [Validation(58/-1)] Loss:  0.000785 Accuracy:  1.0000
# [Training(59/-1)] Loss:  0.001060 Accuracy:  1.0000
# [Validation(59/-1)] Loss:  0.002190 Accuracy:  1.0000
# [Training(60/-1)] Loss:  0.001066 Accuracy:  1.0000
# [Validation(60/-1)] Loss:  0.009140 Accuracy:  1.0000
# [Training(61/-1)] Loss:  0.132701 Accuracy:  0.9429
# [Validation(61/-1)] Loss:  0.000083 Accuracy:  1.0000
# [Training(62/-1)] Loss:  0.000024 Accuracy:  1.0000
# [Validation(62/-1)] Loss:  0.108934 Accuracy:  0.9714
# [Training(63/-1)] Loss:  0.074217 Accuracy:  0.9714
# [Validation(63/-1)] Loss:  0.016102 Accuracy:  1.0000
# [Training(64/-1)] Loss:  0.000020 Accuracy:  1.0000
# [Validation(64/-1)] Loss:  0.003693 Accuracy:  1.0000
# [Training(65/-1)] Loss:  0.024470 Accuracy:  0.9810
# [Validation(65/-1)] Loss:  0.000009 Accuracy:  1.0000
# [Training(66/-1)] Loss:  0.000447 Accuracy:  1.0000
# [Validation(66/-1)] Loss:  0.000006 Accuracy:  1.0000
# [Training(67/-1)] Loss:  0.000027 Accuracy:  1.0000
# [Validation(67/-1)] Loss:  0.000203 Accuracy:  1.0000
# [Training(68/-1)] Loss:  0.000772 Accuracy:  1.0000
# [Validation(68/-1)] Loss:  0.009613 Accuracy:  0.9905
# [Training(69/-1)] Loss:  0.016461 Accuracy:  0.9905
# [Validation(69/-1)] Loss:  0.006229 Accuracy:  1.0000
# [Training(70/-1)] Loss:  0.018611 Accuracy:  0.9905
# [Validation(70/-1)] Loss:  0.000115 Accuracy:  1.0000
# [Training(71/-1)] Loss:  0.535890 Accuracy:  0.9048
# [Validation(71/-1)] Loss:  0.000002 Accuracy:  1.0000
# [Training(72/-1)] Loss:  0.000003 Accuracy:  1.0000
# [Validation(72/-1)] Loss:  0.011593 Accuracy:  0.9905
# [Training(73/-1)] Loss:  0.008842 Accuracy:  0.9905
# [Validation(73/-1)] Loss:  0.172170 Accuracy:  0.9476
# [Training(74/-1)] Loss:  0.514695 Accuracy:  0.9333
# [Validation(74/-1)] Loss:  0.039105 Accuracy:  0.9905
# [Training(75/-1)] Loss:  0.176701 Accuracy:  0.9476
# [Validation(75/-1)] Loss:  0.000057 Accuracy:  1.0000
# [Training(76/-1)] Loss:  0.000260 Accuracy:  1.0000
# [Validation(76/-1)] Loss:  0.000029 Accuracy:  1.0000
# [Training(77/-1)] Loss:  0.000025 Accuracy:  1.0000
# [Validation(77/-1)] Loss:  0.000459 Accuracy:  1.0000
# [Training(78/-1)] Loss:  0.000428 Accuracy:  1.0000
# [Validation(78/-1)] Loss:  0.034508 Accuracy:  0.9810
# [Training(79/-1)] Loss:  0.318103 Accuracy:  0.9143
# [Validation(79/-1)] Loss:  0.014285 Accuracy:  0.9905
# [Training(80/-1)] Loss:  0.178581 Accuracy:  0.9524
# [Validation(80/-1)] Loss:  0.000605 Accuracy:  1.0000
# [Training(81/-1)] Loss:  0.000552 Accuracy:  1.0000
# [Validation(81/-1)] Loss:  0.000291 Accuracy:  1.0000
# [Training(82/-1)] Loss:  0.000260 Accuracy:  1.0000
# [Validation(82/-1)] Loss:  0.000498 Accuracy:  1.0000
# [Training(83/-1)] Loss:  0.001068 Accuracy:  1.0000
# [Validation(83/-1)] Loss:  0.001804 Accuracy:  1.0000
# [+] Training model for /pivot_args_generator/Select@@3
# [Training(1/-1)] Loss:  1.650651 Accuracy:  0.1667
# [Validation(1/-1)] Loss:  1.653391 Accuracy:  0.1952
# [Training(2/-1)] Loss:  1.653228 Accuracy:  0.1952
# [Validation(2/-1)] Loss:  1.652600 Accuracy:  0.1952
# [Training(3/-1)] Loss:  1.652588 Accuracy:  0.1952
# [Validation(3/-1)] Loss:  1.652678 Accuracy:  0.1952
# [Training(4/-1)] Loss:  1.652685 Accuracy:  0.1952
# [Validation(4/-1)] Loss:  1.652644 Accuracy:  0.2905
# [Training(5/-1)] Loss:  1.652638 Accuracy:  0.2905
# [Validation(5/-1)] Loss:  1.652633 Accuracy:  0.1952
# [Training(6/-1)] Loss:  1.652609 Accuracy:  0.1952
# [Validation(6/-1)] Loss:  1.652609 Accuracy:  0.1952
# [Training(7/-1)] Loss:  1.652599 Accuracy:  0.1952
# [Validation(7/-1)] Loss:  1.652562 Accuracy:  0.1952
# [Training(8/-1)] Loss:  1.652551 Accuracy:  0.1952
# [Validation(8/-1)] Loss:  1.652487 Accuracy:  0.1952
# [Training(9/-1)] Loss:  1.652482 Accuracy:  0.1952
# [Validation(9/-1)] Loss:  1.652383 Accuracy:  0.1952
# [Training(10/-1)] Loss:  1.652388 Accuracy:  0.1952
# [Validation(10/-1)] Loss:  1.652254 Accuracy:  0.1952
# [Training(11/-1)] Loss:  1.652267 Accuracy:  0.1952
# [Validation(11/-1)] Loss:  1.652076 Accuracy:  0.1952
# [Training(12/-1)] Loss:  1.652071 Accuracy:  0.1952
# [Validation(12/-1)] Loss:  1.651838 Accuracy:  0.1952
# [Training(13/-1)] Loss:  1.651809 Accuracy:  0.1952
# [Validation(13/-1)] Loss:  1.651517 Accuracy:  0.1952
# [Training(14/-1)] Loss:  1.651504 Accuracy:  0.1952
# [Validation(14/-1)] Loss:  1.651082 Accuracy:  0.1952
# [Training(15/-1)] Loss:  1.651073 Accuracy:  0.1952
# [Validation(15/-1)] Loss:  1.650483 Accuracy:  0.1952
# [Training(16/-1)] Loss:  1.650521 Accuracy:  0.1952
# [Validation(16/-1)] Loss:  1.649723 Accuracy:  0.1952
# [Training(17/-1)] Loss:  1.649660 Accuracy:  0.1952
# [Validation(17/-1)] Loss:  1.648583 Accuracy:  0.1952
# [Training(18/-1)] Loss:  1.648524 Accuracy:  0.1952
# [Validation(18/-1)] Loss:  1.647240 Accuracy:  0.1952
# [Training(19/-1)] Loss:  1.647265 Accuracy:  0.1952
# [Validation(19/-1)] Loss:  1.645523 Accuracy:  0.1952
# [Training(20/-1)] Loss:  1.645441 Accuracy:  0.1952
# [Validation(20/-1)] Loss:  1.643932 Accuracy:  0.1952
# [Training(21/-1)] Loss:  1.643960 Accuracy:  0.1952
# [Validation(21/-1)] Loss:  1.642181 Accuracy:  0.1952
# [Training(22/-1)] Loss:  1.642163 Accuracy:  0.1952
# [Validation(22/-1)] Loss:  1.640489 Accuracy:  0.1952
# [Training(23/-1)] Loss:  1.640502 Accuracy:  0.1952
# [Validation(23/-1)] Loss:  1.639137 Accuracy:  0.1952
# [Training(24/-1)] Loss:  1.638968 Accuracy:  0.1952
# [Validation(24/-1)] Loss:  2.074888 Accuracy:  0.1952
# [Training(25/-1)] Loss:  2.076053 Accuracy:  0.1952
# [Validation(25/-1)] Loss:  1.638897 Accuracy:  0.1952
# [Training(26/-1)] Loss:  1.638696 Accuracy:  0.1952
# [Validation(26/-1)] Loss:  1.639258 Accuracy:  0.1952
# [Training(27/-1)] Loss:  1.639221 Accuracy:  0.1952
# [Validation(27/-1)] Loss:  1.639248 Accuracy:  0.1952
# [Training(28/-1)] Loss:  1.639376 Accuracy:  0.1952
# [Validation(28/-1)] Loss:  1.638772 Accuracy:  0.1952
# [Training(29/-1)] Loss:  1.638795 Accuracy:  0.1952
# [Validation(29/-1)] Loss:  1.638832 Accuracy:  0.1952
# [Training(30/-1)] Loss:  1.638920 Accuracy:  0.1952
# [Validation(30/-1)] Loss:  1.638607 Accuracy:  0.1952
# [Training(31/-1)] Loss:  1.638542 Accuracy:  0.1952
# [Validation(31/-1)] Loss:  1.638404 Accuracy:  0.1952
# [Training(32/-1)] Loss:  1.638358 Accuracy:  0.1952
# [Validation(32/-1)] Loss:  1.638243 Accuracy:  0.1952
# [Training(33/-1)] Loss:  1.638380 Accuracy:  0.1952
# [Validation(33/-1)] Loss:  1.637955 Accuracy:  0.1952
# [Training(34/-1)] Loss:  1.638113 Accuracy:  0.1952
# [Validation(34/-1)] Loss:  1.637394 Accuracy:  0.1952
# [Training(35/-1)] Loss:  1.637519 Accuracy:  0.1952
# [Validation(35/-1)] Loss:  1.637139 Accuracy:  0.1952
# [Training(36/-1)] Loss:  1.637092 Accuracy:  0.1952
# [Validation(36/-1)] Loss:  1.636691 Accuracy:  0.1952
# [Training(37/-1)] Loss:  1.636938 Accuracy:  0.1952
# [Validation(37/-1)] Loss:  1.635964 Accuracy:  0.1952
# [Training(38/-1)] Loss:  1.636020 Accuracy:  0.1952
# [Validation(38/-1)] Loss:  1.635502 Accuracy:  0.1952
# [Training(39/-1)] Loss:  1.635502 Accuracy:  0.1952
# [Validation(39/-1)] Loss:  1.634835 Accuracy:  0.1952
# [Training(40/-1)] Loss:  1.634874 Accuracy:  0.1952
# [Validation(40/-1)] Loss:  1.634028 Accuracy:  0.1952
# [Training(41/-1)] Loss:  1.634125 Accuracy:  0.1952
# [Validation(41/-1)] Loss:  1.633596 Accuracy:  0.1952
# [Training(42/-1)] Loss:  1.633455 Accuracy:  0.1952
# [Validation(42/-1)] Loss:  1.632717 Accuracy:  0.1952
# [Training(43/-1)] Loss:  1.632609 Accuracy:  0.1952
# [Validation(43/-1)] Loss:  1.631888 Accuracy:  0.1952
# [Training(44/-1)] Loss:  1.631800 Accuracy:  0.1952
# [Validation(44/-1)] Loss:  1.631153 Accuracy:  0.1952
# [Training(45/-1)] Loss:  1.631131 Accuracy:  0.1952
# [Validation(45/-1)] Loss:  1.630298 Accuracy:  0.1952
# [Training(46/-1)] Loss:  1.630376 Accuracy:  0.1952
# [Validation(46/-1)] Loss:  1.629393 Accuracy:  0.1952
# [Training(47/-1)] Loss:  1.629449 Accuracy:  0.1952
# [Validation(47/-1)] Loss:  1.628624 Accuracy:  0.1952
# [Training(48/-1)] Loss:  1.628702 Accuracy:  0.1952
# [Validation(48/-1)] Loss:  1.627658 Accuracy:  0.1952
# [Training(49/-1)] Loss:  1.627818 Accuracy:  0.1952
# [Validation(49/-1)] Loss:  1.626722 Accuracy:  0.1952
# [Training(50/-1)] Loss:  1.626768 Accuracy:  0.1952
# [Validation(50/-1)] Loss:  1.625799 Accuracy:  0.1952
# [Training(51/-1)] Loss:  1.625863 Accuracy:  0.1952
# [Validation(51/-1)] Loss:  1.624815 Accuracy:  0.1952
# [Training(52/-1)] Loss:  1.624939 Accuracy:  0.1952
# [Validation(52/-1)] Loss:  1.623762 Accuracy:  0.1952
# [Training(53/-1)] Loss:  1.623753 Accuracy:  0.1952
# [Validation(53/-1)] Loss:  1.622752 Accuracy:  0.1952
# [Training(54/-1)] Loss:  1.622824 Accuracy:  0.1952
# [Validation(54/-1)] Loss:  1.621735 Accuracy:  0.1952
# [Training(55/-1)] Loss:  1.621812 Accuracy:  0.1952
# [Validation(55/-1)] Loss:  1.620604 Accuracy:  0.1952
# [Training(56/-1)] Loss:  1.620573 Accuracy:  0.1952
# [Validation(56/-1)] Loss:  1.619479 Accuracy:  0.1952
# [Training(57/-1)] Loss:  1.619588 Accuracy:  0.1952
# [Validation(57/-1)] Loss:  1.618300 Accuracy:  0.1952
# [Training(58/-1)] Loss:  1.618393 Accuracy:  0.1952
# [Validation(58/-1)] Loss:  1.617094 Accuracy:  0.1952
# [Training(59/-1)] Loss:  1.617067 Accuracy:  0.1952
# [Validation(59/-1)] Loss:  1.615860 Accuracy:  0.1952
# [Training(60/-1)] Loss:  1.615805 Accuracy:  0.1952
# [Validation(60/-1)] Loss:  1.614386 Accuracy:  0.1952
# [Training(61/-1)] Loss:  1.614052 Accuracy:  0.1952
# [Validation(61/-1)] Loss:  1.612875 Accuracy:  0.1952
# [Training(62/-1)] Loss:  1.612849 Accuracy:  0.1952
# [Validation(62/-1)] Loss:  1.611340 Accuracy:  0.1952
# [Training(63/-1)] Loss:  1.611699 Accuracy:  0.1952
# [Validation(63/-1)] Loss:  1.610220 Accuracy:  0.1952
# [Training(64/-1)] Loss:  1.610438 Accuracy:  0.1952
# [Validation(64/-1)] Loss:  1.609905 Accuracy:  0.1952
# [Training(65/-1)] Loss:  1.609625 Accuracy:  0.1952
# [Validation(65/-1)] Loss:  1.607047 Accuracy:  0.1952
# [Training(66/-1)] Loss:  1.606612 Accuracy:  0.1952
# [Validation(66/-1)] Loss:  1.603889 Accuracy:  0.2095
# [Training(67/-1)] Loss:  1.603279 Accuracy:  0.2714
# [Validation(67/-1)] Loss:  1.609169 Accuracy:  0.2381
# [Training(68/-1)] Loss:  1.608521 Accuracy:  0.1952
# [Validation(68/-1)] Loss:  1.604256 Accuracy:  0.2143
# [Training(69/-1)] Loss:  1.604354 Accuracy:  0.1952
# [Validation(69/-1)] Loss:  1.598192 Accuracy:  0.1952
# [Training(70/-1)] Loss:  1.598612 Accuracy:  0.1952
# [Validation(70/-1)] Loss:  1.598393 Accuracy:  0.2286
# [Training(71/-1)] Loss:  1.598308 Accuracy:  0.2238
# [Validation(71/-1)] Loss:  1.597045 Accuracy:  0.2667
# [Training(72/-1)] Loss:  1.597909 Accuracy:  0.1952
# [Validation(72/-1)] Loss:  1.590957 Accuracy:  0.1952
# [Training(73/-1)] Loss:  1.590787 Accuracy:  0.1952
# [Validation(73/-1)] Loss:  1.585966 Accuracy:  0.1952
# [Training(74/-1)] Loss:  1.585525 Accuracy:  0.1952
# [Validation(74/-1)] Loss:  1.585146 Accuracy:  0.1952
# [Training(75/-1)] Loss:  1.587734 Accuracy:  0.1952
# [Validation(75/-1)] Loss:  1.577920 Accuracy:  0.1952
# [Training(76/-1)] Loss:  1.577433 Accuracy:  0.2095
# [Validation(76/-1)] Loss:  1.575194 Accuracy:  0.1952
# [Training(77/-1)] Loss:  1.574959 Accuracy:  0.1952
# [Validation(77/-1)] Loss:  1.572975 Accuracy:  0.1952
# [Training(78/-1)] Loss:  1.573450 Accuracy:  0.1952
# [Validation(78/-1)] Loss:  1.568194 Accuracy:  0.1952
# [Training(79/-1)] Loss:  1.567548 Accuracy:  0.1952
# [Validation(79/-1)] Loss:  1.561422 Accuracy:  0.2095
# [Training(80/-1)] Loss:  1.560474 Accuracy:  0.1952
# [Validation(80/-1)] Loss:  1.545983 Accuracy:  0.2667
# [Training(81/-1)] Loss:  1.543511 Accuracy:  0.2429
# [Validation(81/-1)] Loss:  1.531081 Accuracy:  0.5143
# [Training(82/-1)] Loss:  1.530380 Accuracy:  0.5571
# [Validation(82/-1)] Loss:  1.496575 Accuracy:  0.6143
# [Training(83/-1)] Loss:  1.502861 Accuracy:  0.6762
# [Validation(83/-1)] Loss:  1.455139 Accuracy:  0.3476
# [Training(84/-1)] Loss:  1.462480 Accuracy:  0.5714
# [Validation(84/-1)] Loss:  1.328524 Accuracy:  0.7524
# [Training(85/-1)] Loss:  1.319680 Accuracy:  0.7524
# [Validation(85/-1)] Loss:  1.192851 Accuracy:  0.7476
# [Training(86/-1)] Loss:  1.209450 Accuracy:  0.7095
# [Validation(86/-1)] Loss:  1.040067 Accuracy:  0.6762
# [Training(87/-1)] Loss:  1.039231 Accuracy:  0.6714
# [Validation(87/-1)] Loss:  0.975355 Accuracy:  0.5381
# [Training(88/-1)] Loss:  0.983338 Accuracy:  0.5333
# [Validation(88/-1)] Loss:  0.929986 Accuracy:  0.7524
# [Training(89/-1)] Loss:  0.849548 Accuracy:  0.8048
# [Validation(89/-1)] Loss:  0.898745 Accuracy:  0.7524
# [Training(90/-1)] Loss:  0.968098 Accuracy:  0.7762
# [Validation(90/-1)] Loss:  0.670226 Accuracy:  0.7762
# [Training(91/-1)] Loss:  0.678291 Accuracy:  0.7667
# [Validation(91/-1)] Loss:  0.919303 Accuracy:  0.5571
# [Training(92/-1)] Loss:  0.802089 Accuracy:  0.6857
# [Validation(92/-1)] Loss:  0.635300 Accuracy:  0.7714
# [Training(93/-1)] Loss:  0.616163 Accuracy:  0.7524
# [Validation(93/-1)] Loss:  0.726548 Accuracy:  0.6905
# [Training(94/-1)] Loss:  0.731011 Accuracy:  0.6905
# [Validation(94/-1)] Loss:  0.803198 Accuracy:  0.4714
# [Training(95/-1)] Loss:  0.806613 Accuracy:  0.4714
# [Validation(95/-1)] Loss:  0.788804 Accuracy:  0.4476
# [Training(96/-1)] Loss:  0.811003 Accuracy:  0.4143
# [Validation(96/-1)] Loss:  0.727912 Accuracy:  0.4476
# [Training(97/-1)] Loss:  0.728313 Accuracy:  0.4667
# [Validation(97/-1)] Loss:  0.708678 Accuracy:  0.5238
# [Training(98/-1)] Loss:  0.696565 Accuracy:  0.5952
# [Validation(98/-1)] Loss:  0.676250 Accuracy:  0.6048
# [Training(99/-1)] Loss:  0.663373 Accuracy:  0.6000
# [Validation(99/-1)] Loss:  0.604546 Accuracy:  0.6857
# [Training(100/-1)] Loss:  1.129681 Accuracy:  0.6429
# [Validation(100/-1)] Loss:  0.616981 Accuracy:  0.7286
# [Training(101/-1)] Loss:  0.671209 Accuracy:  0.6143
# [Validation(101/-1)] Loss:  0.554324 Accuracy:  0.8429
# [Training(102/-1)] Loss:  0.485227 Accuracy:  0.8571
# [Validation(102/-1)] Loss:  0.383095 Accuracy:  0.8667
# [Training(103/-1)] Loss:  0.478000 Accuracy:  0.8429
# [Validation(103/-1)] Loss:  0.928363 Accuracy:  0.7000
# [Training(104/-1)] Loss:  0.746576 Accuracy:  0.7048
# [Validation(104/-1)] Loss:  0.926381 Accuracy:  0.6905
# [Training(105/-1)] Loss:  1.033116 Accuracy:  0.6714
# [Validation(105/-1)] Loss:  0.724144 Accuracy:  0.6857
# [Training(106/-1)] Loss:  0.541434 Accuracy:  0.7048
# [Validation(106/-1)] Loss:  0.404213 Accuracy:  0.8619
# [Training(107/-1)] Loss:  0.440336 Accuracy:  0.8333
# [Validation(107/-1)] Loss:  0.471922 Accuracy:  0.8429
# [Training(108/-1)] Loss:  0.542498 Accuracy:  0.8429
# [Validation(108/-1)] Loss:  0.592751 Accuracy:  0.8286
# [Training(109/-1)] Loss:  0.605160 Accuracy:  0.8286
# [Validation(109/-1)] Loss:  0.604768 Accuracy:  0.8238
# [Training(110/-1)] Loss:  0.830516 Accuracy:  0.8095
# [Validation(110/-1)] Loss:  0.518701 Accuracy:  0.8381
# [Training(111/-1)] Loss:  0.591331 Accuracy:  0.8286
# [Validation(111/-1)] Loss:  0.444648 Accuracy:  0.8429
# [Training(112/-1)] Loss:  0.475393 Accuracy:  0.8429
# [Validation(112/-1)] Loss:  0.400205 Accuracy:  0.8476
# [Training(113/-1)] Loss:  0.403065 Accuracy:  0.8619
# [Validation(113/-1)] Loss:  0.385924 Accuracy:  0.8619
# [Training(114/-1)] Loss:  0.418073 Accuracy:  0.8524
# [Validation(114/-1)] Loss:  0.396668 Accuracy:  0.8667
# [Training(115/-1)] Loss:  0.390899 Accuracy:  0.8619
# [Validation(115/-1)] Loss:  0.489929 Accuracy:  0.6905
# [Training(116/-1)] Loss:  0.713263 Accuracy:  0.7333
# [Validation(116/-1)] Loss:  0.448217 Accuracy:  0.8238
# [Training(117/-1)] Loss:  0.403668 Accuracy:  0.8476
# [Validation(117/-1)] Loss:  0.372150 Accuracy:  0.8667
# [Training(118/-1)] Loss:  0.569261 Accuracy:  0.7429
# [Validation(118/-1)] Loss:  0.329596 Accuracy:  0.8762
# [Training(119/-1)] Loss:  0.334142 Accuracy:  0.8667
# [Validation(119/-1)] Loss:  0.336483 Accuracy:  0.8667
# [Training(120/-1)] Loss:  0.346428 Accuracy:  0.8810
# [Validation(120/-1)] Loss:  0.372499 Accuracy:  0.8571
# [Training(121/-1)] Loss:  0.321219 Accuracy:  0.8667
# [Validation(121/-1)] Loss:  0.411916 Accuracy:  0.8476
# [Training(122/-1)] Loss:  0.419776 Accuracy:  0.8381
# [Validation(122/-1)] Loss:  0.427309 Accuracy:  0.8429
# [Training(123/-1)] Loss:  0.566393 Accuracy:  0.8333
# [Validation(123/-1)] Loss:  0.405938 Accuracy:  0.8429
# [Training(124/-1)] Loss:  0.383859 Accuracy:  0.8476
# [Validation(124/-1)] Loss:  0.364980 Accuracy:  0.8476
# [Training(125/-1)] Loss:  0.367950 Accuracy:  0.8476
# [Validation(125/-1)] Loss:  0.313052 Accuracy:  0.8667
# [Training(126/-1)] Loss:  0.308218 Accuracy:  0.8762
# [Validation(126/-1)] Loss:  0.268676 Accuracy:  0.8762
# [Training(127/-1)] Loss:  0.270979 Accuracy:  0.8762
# [Validation(127/-1)] Loss:  0.234605 Accuracy:  0.9143
# [Training(128/-1)] Loss:  0.295493 Accuracy:  0.8762
# [Validation(128/-1)] Loss:  0.217149 Accuracy:  0.9429
# [Training(129/-1)] Loss:  0.213576 Accuracy:  0.9524
# [Validation(129/-1)] Loss:  0.206465 Accuracy:  0.9524
# [Training(130/-1)] Loss:  0.193734 Accuracy:  0.9476
# [Validation(130/-1)] Loss:  0.202415 Accuracy:  0.9524
# [Training(131/-1)] Loss:  0.178262 Accuracy:  0.9524
# [Validation(131/-1)] Loss:  0.203642 Accuracy:  0.9381
# [Training(132/-1)] Loss:  0.314672 Accuracy:  0.8952
# [Validation(132/-1)] Loss:  0.175348 Accuracy:  0.9571
# [Training(133/-1)] Loss:  0.163982 Accuracy:  0.9476
# [Validation(133/-1)] Loss:  0.147123 Accuracy:  0.9571
# [Training(134/-1)] Loss:  0.156929 Accuracy:  0.9524
# [Validation(134/-1)] Loss:  0.122799 Accuracy:  0.9667
# [Training(135/-1)] Loss:  0.112046 Accuracy:  0.9810
# [Validation(135/-1)] Loss:  0.099857 Accuracy:  0.9905
# [Training(136/-1)] Loss:  0.135165 Accuracy:  0.9619
# [Validation(136/-1)] Loss:  0.074745 Accuracy:  0.9905
# [Training(137/-1)] Loss:  0.105420 Accuracy:  1.0000
# [Validation(137/-1)] Loss:  0.065812 Accuracy:  0.9905
# [Training(138/-1)] Loss:  0.055081 Accuracy:  0.9952
# [Validation(138/-1)] Loss:  0.068566 Accuracy:  0.9857
# [Training(139/-1)] Loss:  0.096585 Accuracy:  1.0000
# [Validation(139/-1)] Loss:  0.115112 Accuracy:  0.9524
# [Training(140/-1)] Loss:  0.343492 Accuracy:  0.8619
# [Validation(140/-1)] Loss:  0.168442 Accuracy:  0.9524
# [Training(141/-1)] Loss:  0.094966 Accuracy:  0.9810
# [Validation(141/-1)] Loss:  0.178280 Accuracy:  0.9524
# [Training(142/-1)] Loss:  0.267156 Accuracy:  0.9143
# [Validation(142/-1)] Loss:  0.141100 Accuracy:  0.9524
# [Training(143/-1)] Loss:  0.282212 Accuracy:  0.8810
# [Validation(143/-1)] Loss:  0.081776 Accuracy:  0.9667
# [Training(144/-1)] Loss:  0.044116 Accuracy:  0.9857
# [Validation(144/-1)] Loss:  0.040953 Accuracy:  0.9857
# [Training(145/-1)] Loss:  0.201969 Accuracy:  0.9429
# [Validation(145/-1)] Loss:  0.019132 Accuracy:  1.0000
# [Training(146/-1)] Loss:  0.025150 Accuracy:  1.0000
# [Validation(146/-1)] Loss:  0.031821 Accuracy:  0.9857
# [Training(147/-1)] Loss:  0.031590 Accuracy:  0.9952
# [Validation(147/-1)] Loss:  0.058510 Accuracy:  0.9857
# [Training(148/-1)] Loss:  0.058922 Accuracy:  0.9857
# [Validation(148/-1)] Loss:  0.080638 Accuracy:  0.9762
# [Training(149/-1)] Loss:  0.066665 Accuracy:  0.9857
# [Validation(149/-1)] Loss:  0.080215 Accuracy:  0.9667
# [Training(150/-1)] Loss:  0.036284 Accuracy:  0.9857
# [Validation(150/-1)] Loss:  0.062082 Accuracy:  0.9857
# [Training(151/-1)] Loss:  0.559389 Accuracy:  0.8381
# [Validation(151/-1)] Loss:  0.029453 Accuracy:  0.9857
# [Training(152/-1)] Loss:  0.068167 Accuracy:  0.9762
# [Validation(152/-1)] Loss:  0.026576 Accuracy:  0.9952
# [Training(153/-1)] Loss:  0.024121 Accuracy:  0.9952
# [Validation(153/-1)] Loss:  0.039850 Accuracy:  0.9905
# [Training(154/-1)] Loss:  0.030628 Accuracy:  0.9952
# [Validation(154/-1)] Loss:  0.053467 Accuracy:  0.9905
# [Training(155/-1)] Loss:  0.033146 Accuracy:  0.9905
# [Validation(155/-1)] Loss:  0.069097 Accuracy:  0.9857
# [Training(156/-1)] Loss:  0.069740 Accuracy:  0.9905
# [Validation(156/-1)] Loss:  0.079560 Accuracy:  0.9857
# [Training(157/-1)] Loss:  0.062915 Accuracy:  0.9905
# [Validation(157/-1)] Loss:  0.088541 Accuracy:  0.9857
# [Training(158/-1)] Loss:  0.137585 Accuracy:  0.9667
# [Validation(158/-1)] Loss:  0.076685 Accuracy:  0.9857
# [Training(159/-1)] Loss:  0.062596 Accuracy:  0.9905
# [Validation(159/-1)] Loss:  0.065698 Accuracy:  0.9857
# [Training(160/-1)] Loss:  0.053589 Accuracy:  0.9905
# [Validation(160/-1)] Loss:  0.055691 Accuracy:  0.9857
# [Training(161/-1)] Loss:  0.061351 Accuracy:  0.9810
# [Validation(161/-1)] Loss:  0.044710 Accuracy:  0.9857
# [Training(162/-1)] Loss:  0.056420 Accuracy:  0.9762
# [Validation(162/-1)] Loss:  0.034180 Accuracy:  0.9905
# [Training(163/-1)] Loss:  0.032082 Accuracy:  0.9905
# [Validation(163/-1)] Loss:  0.028055 Accuracy:  0.9905
# [Training(164/-1)] Loss:  0.045181 Accuracy:  0.9810
# [Validation(164/-1)] Loss:  0.023577 Accuracy:  0.9952
# [Training(165/-1)] Loss:  0.032190 Accuracy:  0.9905
# [Validation(165/-1)] Loss:  0.022283 Accuracy:  1.0000
# [Training(166/-1)] Loss:  0.056825 Accuracy:  0.9810
# [Validation(166/-1)] Loss:  0.026801 Accuracy:  0.9857
# [Training(167/-1)] Loss:  0.021805 Accuracy:  1.0000
# [Validation(167/-1)] Loss:  0.039702 Accuracy:  0.9857
# [Training(168/-1)] Loss:  0.022413 Accuracy:  1.0000
# [Validation(168/-1)] Loss:  0.052218 Accuracy:  0.9762
# [Training(169/-1)] Loss:  0.052109 Accuracy:  0.9762
# [Validation(169/-1)] Loss:  0.054298 Accuracy:  0.9762
# [Training(170/-1)] Loss:  0.089693 Accuracy:  0.9667
# [Validation(170/-1)] Loss:  0.042963 Accuracy:  0.9857
# [Training(171/-1)] Loss:  0.263477 Accuracy:  0.8762
# [Validation(171/-1)] Loss:  0.022361 Accuracy:  1.0000

# %%
model.save("trained_model")

# %% [markdown]
# ## Putting it All Together

# %% [markdown]
# Let's assign the model we just trained to our original generator

# %%
pivot_args_generator.set_model(model)

# %% [markdown]
# Let's try running our trained generator on an unseen input-output example

# %%
unseen_input_df = pd.DataFrame({
    'series': {0: 'A', 1: 'B', 2: 'C', 3: 'A', 4: 'B', 5: 'C', 6: 'A', 7: 'B', 8: 'C', 9: 'A', 10: 'B', 11: 'C', 12: 'A', 13: 'B', 14: 'C'},
    'step': {0: '100', 1: '100', 2: '100', 3: '101', 4: '101', 5: '101', 6: '102', 7: '102', 8: '102', 9: '103', 10: '103', 11: '103', 12: '104', 13: '104', 14: '104'},
    'value': {0: '1000', 1: '1001', 2: '1002', 3: '1003', 4: '1004', 5: '1005', 6: '1006', 7: '1007', 8: '1008', 9: '1009', 10: '1010', 11: '1011', 12: '1012', 13: '1013', 14: '1014'}
})
unseen_input_df
# Out:
#    series step value
# 0       A  100  1000
# 1       B  100  1001
# 2       C  100  1002
# 3       A  101  1003
# 4       B  101  1004
# 5       C  101  1005
# 6       A  102  1006
# 7       B  102  1007
# 8       C  102  1008
# 9       A  103  1009
# 10      B  103  1010
# 11      C  103  1011
# 12      A  104  1012
# 13      B  104  1013
# 14      C  104  1014

# %%
unseen_output_df = pd.DataFrame({
    'A': {'100': '1000', '101': '1003', '102': '1006', '103': '1009', '104': '1012'},
    'B': {'100': '1001', '101': '1004', '102': '1007', '103': '1010', '104': '1013'},
    'C': {'100': '1002', '101': '1005', '102': '1008', '103': '1011', '104': '1014'}
})
unseen_output_df
# Out:
#         A     B     C
# 100  1000  1001  1002
# 101  1003  1004  1005
# 102  1006  1007  1008
# 103  1009  1010  1011
# 104  1012  1013  1014

# %%
synthesize(unseen_input_df, unseen_output_df)
# Out:
# Trying Combination: {'columns': 'series', 'index': 'step', 'values': 'value'}
# Solution Found: {'columns': 'series', 'index': 'step', 'values': 'value'}

# %% [markdown]
# Success! As you can see, our trained generator found the solution on the *first* attempt! What is even more remarkable is that we trained it on a very small amount of data, data that looked very different from the training dataset.
#
# *TODO: Need a better summary cell*
