# %% [markdown]
# # Building a Synthesizer for Pivot
#
# In this tutorial, we will build a simple but efficient synthesizer for the Pandas [pivot](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.pivot.html) function. More concretely, given an input dataframe and a desired output dataframe, our synthesizer will output the arguments that need to be passed to pivot that can reproduce the desired output.

# %% [markdown]
# ## Arguments Generator for Pivot
# First let us define a generator that will be our synthesis engine for pivot. As mentioned earlier, this generator will enumerate possible argument combinations. Here is one version which simply selects one of the columns for each of the arguments (or the default value of `None`).

# %%
from atlas import generator

@generator
def pivot_args_generator(input_df):
    arg_columns = Select([None] + list(input_df.columns))
    arg_index = Select([None] + list(input_df.columns))
    arg_values = Select([None] + list(input_df.columns))
    
    return {'index': arg_index, 'columns': arg_columns, 'values': arg_values}

# %% [markdown]
# Now let's try running it on a sample dataframe

# %%
import pandas as pd
df = pd.DataFrame({
  'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
  'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
  'baz': [10, 20, 30, 40, 50, 60],
})
df
# Out:
#    foo bar  baz
# 0  one   A   10
# 1  one   B   20
# 2  one   C   30
# 3  two   A   40
# 4  two   B   50
# 5  two   C   60

# %%
for args in pivot_args_generator.generate(df):
    print(args)
# Out:
# {'index': None, 'columns': None, 'values': None}
# {'index': None, 'columns': None, 'values': 'foo'}
# {'index': None, 'columns': None, 'values': 'bar'}
# {'index': None, 'columns': None, 'values': 'baz'}
# {'index': 'foo', 'columns': None, 'values': None}
# {'index': 'foo', 'columns': None, 'values': 'foo'}
# {'index': 'foo', 'columns': None, 'values': 'bar'}
# {'index': 'foo', 'columns': None, 'values': 'baz'}
# {'index': 'bar', 'columns': None, 'values': None}
# {'index': 'bar', 'columns': None, 'values': 'foo'}
# {'index': 'bar', 'columns': None, 'values': 'bar'}
# {'index': 'bar', 'columns': None, 'values': 'baz'}
# {'index': 'baz', 'columns': None, 'values': None}
# {'index': 'baz', 'columns': None, 'values': 'foo'}
# {'index': 'baz', 'columns': None, 'values': 'bar'}
# {'index': 'baz', 'columns': None, 'values': 'baz'}
# {'index': None, 'columns': 'foo', 'values': None}
# {'index': None, 'columns': 'foo', 'values': 'foo'}
# {'index': None, 'columns': 'foo', 'values': 'bar'}
# {'index': None, 'columns': 'foo', 'values': 'baz'}
# {'index': 'foo', 'columns': 'foo', 'values': None}
# {'index': 'foo', 'columns': 'foo', 'values': 'foo'}
# {'index': 'foo', 'columns': 'foo', 'values': 'bar'}
# {'index': 'foo', 'columns': 'foo', 'values': 'baz'}
# {'index': 'bar', 'columns': 'foo', 'values': None}
# {'index': 'bar', 'columns': 'foo', 'values': 'foo'}
# {'index': 'bar', 'columns': 'foo', 'values': 'bar'}
# {'index': 'bar', 'columns': 'foo', 'values': 'baz'}
# {'index': 'baz', 'columns': 'foo', 'values': None}
# {'index': 'baz', 'columns': 'foo', 'values': 'foo'}
# {'index': 'baz', 'columns': 'foo', 'values': 'bar'}
# {'index': 'baz', 'columns': 'foo', 'values': 'baz'}
# {'index': None, 'columns': 'bar', 'values': None}
# {'index': None, 'columns': 'bar', 'values': 'foo'}
# {'index': None, 'columns': 'bar', 'values': 'bar'}
# {'index': None, 'columns': 'bar', 'values': 'baz'}
# {'index': 'foo', 'columns': 'bar', 'values': None}
# {'index': 'foo', 'columns': 'bar', 'values': 'foo'}
# {'index': 'foo', 'columns': 'bar', 'values': 'bar'}
# {'index': 'foo', 'columns': 'bar', 'values': 'baz'}
# {'index': 'bar', 'columns': 'bar', 'values': None}
# {'index': 'bar', 'columns': 'bar', 'values': 'foo'}
# {'index': 'bar', 'columns': 'bar', 'values': 'bar'}
# {'index': 'bar', 'columns': 'bar', 'values': 'baz'}
# {'index': 'baz', 'columns': 'bar', 'values': None}
# {'index': 'baz', 'columns': 'bar', 'values': 'foo'}
# {'index': 'baz', 'columns': 'bar', 'values': 'bar'}
# {'index': 'baz', 'columns': 'bar', 'values': 'baz'}
# {'index': None, 'columns': 'baz', 'values': None}
# {'index': None, 'columns': 'baz', 'values': 'foo'}
# {'index': None, 'columns': 'baz', 'values': 'bar'}
# {'index': None, 'columns': 'baz', 'values': 'baz'}
# {'index': 'foo', 'columns': 'baz', 'values': None}
# {'index': 'foo', 'columns': 'baz', 'values': 'foo'}
# {'index': 'foo', 'columns': 'baz', 'values': 'bar'}
# {'index': 'foo', 'columns': 'baz', 'values': 'baz'}
# {'index': 'bar', 'columns': 'baz', 'values': None}
# {'index': 'bar', 'columns': 'baz', 'values': 'foo'}
# {'index': 'bar', 'columns': 'baz', 'values': 'bar'}
# {'index': 'bar', 'columns': 'baz', 'values': 'baz'}
# {'index': 'baz', 'columns': 'baz', 'values': None}
# {'index': 'baz', 'columns': 'baz', 'values': 'foo'}
# {'index': 'baz', 'columns': 'baz', 'values': 'bar'}
# {'index': 'baz', 'columns': 'baz', 'values': 'baz'}

# %% [markdown]
# However, not all the argument combinations printed above are valid. Not convinced? Let's try executing them.

# %%
for args in pivot_args_generator.generate(df):
    print(args, df.pivot(**args))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-bf6bc726e3d4> in <module>()
#       1 for args in pivot_args_generator.generate(df):
# ----> 2     print(args, df.pivot(**args))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     398         cols = [columns] if index is None else [index, columns]
#     399         append = index is None
# --> 400         indexed = self.set_index(cols, append=append)
#     401     else:
#     402         if index is None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4122                         loc = indexer.item()
#    4123                     else:
# -> 4124                         raise ValueError("cannot label index with a null key")
#    4125
#    4126             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key

# %% [markdown]
# Pandas threw an error as our generator is not *precise* while enumerating arguments. That is, it generates argument combinations which cause the pandas pivot function to throw an error. There are a number of hard-to-see constraints embedded in the [documentation](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.pivot.html) for pivot. For example, the columns argument is not marked *Optional* even though it is a keyword argument. We have already done the job of incorporating all these constraints in the generator below.

# %%
@generator
def pivot_args_generator(input_df): 
    def dup_filter(cand):
        try:
            return not any(input_df[[cand, arg_columns]].duplicated())
        except:
            return True

    arg_columns = Select(input_df.columns)
    arg_index = Select([None] + list(filter(dup_filter, set(input_df.columns) - {arg_columns})))

    if input_df.index.nlevels > 1 and arg_index is None:
        arg_values = None
    else:
        arg_values = Select(set(input_df.columns) | {None})

    return {'columns': arg_columns, 'index': arg_index, 'values': arg_values}

# %%
for args in pivot_args_generator.generate(df):
    print(args)
# Out:
# {'columns': 'foo', 'index': None, 'values': 'baz'}
# {'columns': 'foo', 'index': None, 'values': 'foo'}
# {'columns': 'foo', 'index': None, 'values': None}
# {'columns': 'foo', 'index': None, 'values': 'bar'}
# {'columns': 'foo', 'index': 'baz', 'values': 'baz'}
# {'columns': 'foo', 'index': 'baz', 'values': 'foo'}
# {'columns': 'foo', 'index': 'baz', 'values': None}
# {'columns': 'foo', 'index': 'baz', 'values': 'bar'}
# {'columns': 'foo', 'index': 'bar', 'values': 'baz'}
# {'columns': 'foo', 'index': 'bar', 'values': 'foo'}
# {'columns': 'foo', 'index': 'bar', 'values': None}
# {'columns': 'foo', 'index': 'bar', 'values': 'bar'}
# {'columns': 'bar', 'index': None, 'values': 'baz'}
# {'columns': 'bar', 'index': None, 'values': 'foo'}
# {'columns': 'bar', 'index': None, 'values': None}
# {'columns': 'bar', 'index': None, 'values': 'bar'}
# {'columns': 'bar', 'index': 'baz', 'values': 'baz'}
# {'columns': 'bar', 'index': 'baz', 'values': 'foo'}
# {'columns': 'bar', 'index': 'baz', 'values': None}
# {'columns': 'bar', 'index': 'baz', 'values': 'bar'}
# {'columns': 'bar', 'index': 'foo', 'values': 'baz'}
# {'columns': 'bar', 'index': 'foo', 'values': 'foo'}
# {'columns': 'bar', 'index': 'foo', 'values': None}
# {'columns': 'bar', 'index': 'foo', 'values': 'bar'}
# {'columns': 'baz', 'index': None, 'values': 'baz'}
# {'columns': 'baz', 'index': None, 'values': 'foo'}
# {'columns': 'baz', 'index': None, 'values': None}
# {'columns': 'baz', 'index': None, 'values': 'bar'}
# {'columns': 'baz', 'index': 'foo', 'values': 'baz'}
# {'columns': 'baz', 'index': 'foo', 'values': 'foo'}
# {'columns': 'baz', 'index': 'foo', 'values': None}
# {'columns': 'baz', 'index': 'foo', 'values': 'bar'}
# {'columns': 'baz', 'index': 'bar', 'values': 'baz'}
# {'columns': 'baz', 'index': 'bar', 'values': 'foo'}
# {'columns': 'baz', 'index': 'bar', 'values': None}
# {'columns': 'baz', 'index': 'bar', 'values': 'bar'}

# %% [markdown]
# ## Building a Brute-Force Synthesizer
# Given `pivot_args_generator` we are now ready to build our first brute-force synthesizer for pivot. Given an input-output pair, we will simply enumerate and execute all argument combinations till we find the right one.

# %%
from atlas.synthesis.pandas.checker import Checker
def synthesize(input_df, output_df):
    for args in pivot_args_generator.generate(input_df):
        print("Trying Combination:", args)
        result = input_df.pivot(**args)
        if Checker.check(result, output_df):
            print("Solution Found:", args)
            break

# %% [markdown]
# Try it out!

# %%
desired_output = pd.DataFrame({'one': {'A': 10, 'B': 20, 'C': 30}, 'two': {'A': 40, 'B': 50, 'C': 60}})
desired_output
# Out:
#    one  two
# A   10   40
# B   20   50
# C   30   60

# %%
synthesize(df, desired_output)
# Out:
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'baz'}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'foo'}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': None}
# Trying Combination: {'columns': 'foo', 'index': None, 'values': 'bar'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'baz'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'foo'}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': None}
# Trying Combination: {'columns': 'foo', 'index': 'baz', 'values': 'bar'}
# Trying Combination: {'columns': 'foo', 'index': 'bar', 'values': 'baz'}
# Solution Found: {'columns': 'foo', 'index': 'bar', 'values': 'baz'}

# %% [markdown]
# ## Building a Smart Synthesizer
# Our brute-force synthesizer works pretty well, but there's still a lot that can be done. First, notice the number of argument combinations explored before arriving at the solution. For large dataframes the synthesis process may be slow. Second, the generator is not *predictive*. It does not tell us what it thinks are the most promising argument combinations. Rather it just goes over the space of values deterministically.
#
# Let us try to *train* the generator to return argument combinations that are *more likely* to be correct for a given input-output dataframe pair.

# %% [markdown]
# ### Adding Output to the Generator
# You may have noticed that the output dataframe is not visible to the argument generator. In order to build a smarter generator, we need to give it access to the output.

# %%
@generator
def pivot_args_generator(input_df, output_df):
    pass

# %% [markdown]
# ### Adding Context to the Generator
# We will pass a **context** to each of the Select operators that will help them make the the right choices by conditioning on this context. Can you guess what the context will be? That's right, it will simply be the input-output example.

# %%
@generator
def pivot_args_generator(input_df, output_df): 
    def dup_filter(cand):
        try:
            return not any(input_df[[cand, arg_columns]].duplicated())
        except:
            return True

    c = {'Input': input_df, 'Output': output_df}
    arg_columns = Select(input_df.columns, context=c)
    arg_index = Select([None] + list(filter(dup_filter, set(input_df.columns) - {arg_columns})), context=c)

    if input_df.index.nlevels > 1 and arg_index is None:
        arg_values = None
    else:
        arg_values = Select(set(input_df.columns) | {None}, context=c)

    return {'columns': arg_columns, 'index': arg_index, 'values': arg_values}

# %% [markdown]
# Need to modify the `synthesize` procedure a bit as well to sync with the above changes

# %%
def synthesize(input_df, output_df):
    for args in pivot_args_generator.generate(input_df, output_df):
        print("Trying Combination:", args)
        result = input_df.pivot(**args)
        if Checker.check(result, output_df):
            print("Solution Found:", args)
            break

# %% [markdown]
# ## Training the Generator
#
# ### Defining the Model
# We need to define the predictive models that the generator will use to refine its output. In particular, we need to define the models used by the Select operators.
#
# Our overall generator model uses a single Tensorflow Graph-Neural-Network architecture for all the Select operators.
#
# *TODO : Construct graph encoding inside the notebook, and use a PyTorch model using PyTorch Geometric*

# %%
from typing import Mapping, Any, Collection
from atlas.tracing import OpTrace
from atlas.operators import operator
from atlas.models.catalogue import Models
from atlas.models.tensorflow.graphs.operators import SelectGGNN
from atlas.synthesis.pandas.encoders import PandasGraphEncoder

class PivotGeneratorModel(Models.Generators.Imitation.IndependentOperators):
    @operator
    def Select(*args, **kwargs):
        config = {
            'learning_rate': 0.01,
            'node_dimension': 50,
            'classifier_hidden_dims': [50],
            'batch_size': 30000,
            'layer_timesteps': [1, 1, 1]
        }
        
        return PivotSelectModel(config)
    
class PivotSelectModel(SelectGGNN):
    def __init__(self, params: Mapping[str, Any]):
        self.encoder = PandasGraphEncoder()
        params.update({
            'num_node_features': self.encoder.get_num_node_features(),
            'num_edge_types': self.encoder.get_num_edge_types()
        })
        
        super().__init__(params)
        
    def train(self, training_data: Collection[OpTrace], validation_data: Collection[OpTrace], *args, **kwargs):
        encoded_train = [self.encoder.Select(domain=op.domain, 
                                             context=op.context, 
                                             choice=op.choice, 
                                             sid=op.op_info.sid) for op in training_data]
        encoded_valid = [self.encoder.Select(domain=op.domain, 
                                             context=op.context, 
                                             choice=op.choice, 
                                             sid=op.op_info.sid) for op in validation_data]
        super().train(encoded_train, encoded_valid, *args, **kwargs)
        
    def infer(self, domain, context: Any = None, sid: str = '', **kwargs):
        encoding = self.encoder.Select(domain, context, mode='inference', sid=sid)
        inference = super().infer([encoding])[0]
        return [val for val, prob in sorted(inference, key=lambda x: -x[1])]

# %% [markdown]
# ### Gather Training Data
# To gather training data, we will simply take three dataframes, enumerate all possible argument combinations, execute them and collect the output. We will enable tracing to keep track of the operator choices made. We will then retroactively modify the trace to incorporate the resulting output in the context.

# %%
dataframes = [
    pd.DataFrame({
        'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
        'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
        'baz': [10, 20, 30, 40, 50, 60],
    }),

    pd.DataFrame({
        'date': ['1959-03-31 00:00:00'] * 3 + ['1959-06-30 00:00:00'] * 3 + [
            '1959-09-30 00:00:00'] * 3 + ['1959-12-31 00:00:00'],
        'item': ['realgdp', 'infl', 'unemp', 'realgdp', 'infl', 'unemp', 'realgdp', 'infl',
                 'unemp', 'realgdp'],
        'value': [2710.349, 0.001, 5.800, 2778.801, 2.340, 5.100, 2775.488, 2.740, 5.300,
                  2785.204],
    }),

    pd.DataFrame({
        'Date': ['2018-02-18', '2018-02-24', '2018-02-24', '2018-03-01', '2018-03-11', '2018-03-11'],
        'Category': ['Social', 'Lunch', 'Social', 'Lunch', 'Lunch', 'Brunch'],
        'Location': ['Terrace', "Pox", "Gate 320", "Pox", "Cola 543", "Terrace"],
        'Expense': [98.34, 245.63, 121.89, 248.00, 240.40, 561.48],
        'Balance': [9971.66, 9726.03, 9604.14, 9356.04, 9115.74, 8554.26]
    })
]

# %%
traces = []
input_outputs = []
for df in dataframes[:3]:
    for args, trace in pivot_args_generator.with_env(tracing=True).generate(df, None):
        output = df.pivot(**args)
        input_outputs.append((df, output))
        traces.append(trace)
        
# Need to replay as in the previous run as the output was None and 
# consequently the context recorded was incorrect
# The [1] at the end simply extracts the trace part of the resulting tuple
traces = [pivot_args_generator.with_env(replay=trace, tracing=True).call(i, o)[1]
          for (i, o), trace in zip(input_outputs, traces)]

# %% [markdown]
# ### Train the Model
# Let us start training the model

# %%
model = PivotGeneratorModel()
model.train(traces, traces, num_epochs=-1)
# Out:
# 100%|██████████| 210/210 [00:00<00:00, 318094.56it/s]
# 100%|██████████| 210/210 [00:00<00:00, 241647.14it/s]
# [+] Training model for OpInfo(sid='/pivot_args_generator/Select@@1', gen_name='pivot_args_generator', op_type='Select', index=1, gen_group=None, uid=None, tags=None)
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:317: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# [Training(1/-1)] Loss:  1.431255 Accuracy:  0.3238
# [Validation(1/-1)] Loss:  1.412953 Accuracy:  0.3286
# [Training(2/-1)] Loss:  1.412932 Accuracy:  0.3286
# [Validation(2/-1)] Loss:  1.373543 Accuracy:  0.3286
# [Training(3/-1)] Loss:  1.371705 Accuracy:  0.3524
# [Validation(3/-1)] Loss:  1.311079 Accuracy:  0.3286
# [Training(4/-1)] Loss:  1.309602 Accuracy:  0.3286
# [Validation(4/-1)] Loss:  1.270060 Accuracy:  0.3286
# [Training(5/-1)] Loss:  1.270310 Accuracy:  0.3286
# [Validation(5/-1)] Loss:  1.262313 Accuracy:  0.3286
# [Training(6/-1)] Loss:  1.262292 Accuracy:  0.3286
# [Validation(6/-1)] Loss:  1.261103 Accuracy:  0.3286
# [Training(7/-1)] Loss:  1.261276 Accuracy:  0.3286
# [Validation(7/-1)] Loss:  1.261362 Accuracy:  0.3286
# [Training(8/-1)] Loss:  1.261232 Accuracy:  0.3286
# [Validation(8/-1)] Loss:  1.261296 Accuracy:  0.3286
# [Training(9/-1)] Loss:  1.261195 Accuracy:  0.3286
# [Validation(9/-1)] Loss:  1.260799 Accuracy:  0.3286
# [Training(10/-1)] Loss:  1.260785 Accuracy:  0.3286
# [Validation(10/-1)] Loss:  1.261159 Accuracy:  0.3333
# [Training(11/-1)] Loss:  1.261277 Accuracy:  0.3286
# [Validation(11/-1)] Loss:  1.260996 Accuracy:  0.3333
# [Training(12/-1)] Loss:  1.261039 Accuracy:  0.3333
# [Validation(12/-1)] Loss:  1.260363 Accuracy:  0.3286
# [Training(13/-1)] Loss:  1.260219 Accuracy:  0.4143
# [Validation(13/-1)] Loss:  1.258706 Accuracy:  0.4476
# [Training(14/-1)] Loss:  1.258539 Accuracy:  0.4095
# [Validation(14/-1)] Loss:  1.255497 Accuracy:  0.4238
# [Training(15/-1)] Loss:  1.256017 Accuracy:  0.4238
# [Validation(15/-1)] Loss:  1.246439 Accuracy:  0.4048
# [Training(16/-1)] Loss:  1.246755 Accuracy:  0.4095
# [Validation(16/-1)] Loss:  1.227177 Accuracy:  0.4095
# [Training(17/-1)] Loss:  1.229506 Accuracy:  0.4095
# [Validation(17/-1)] Loss:  1.184175 Accuracy:  0.4143
# [Training(18/-1)] Loss:  1.181759 Accuracy:  0.4190
# [Validation(18/-1)] Loss:  1.090005 Accuracy:  0.4619
# [Training(19/-1)] Loss:  1.091183 Accuracy:  0.4714
# [Validation(19/-1)] Loss:  0.938112 Accuracy:  0.4857
# [Training(20/-1)] Loss:  0.940265 Accuracy:  0.4857
# [Validation(20/-1)] Loss:  0.841106 Accuracy:  0.5524
# [Training(21/-1)] Loss:  0.855334 Accuracy:  0.5476
# [Validation(21/-1)] Loss:  0.758871 Accuracy:  0.5524
# [Training(22/-1)] Loss:  0.721954 Accuracy:  0.5762
# [Validation(22/-1)] Loss:  0.731500 Accuracy:  0.5286
# [Training(23/-1)] Loss:  0.729150 Accuracy:  0.5667
# [Validation(23/-1)] Loss:  0.652760 Accuracy:  0.5857
# [Training(24/-1)] Loss:  0.634096 Accuracy:  0.6905
# [Validation(24/-1)] Loss:  0.586622 Accuracy:  0.6476
# [Training(25/-1)] Loss:  0.598216 Accuracy:  0.6476
# [Validation(25/-1)] Loss:  0.502755 Accuracy:  0.7429
# [Training(26/-1)] Loss:  0.568380 Accuracy:  0.6619
# [Validation(26/-1)] Loss:  0.396522 Accuracy:  0.8048
# [Training(27/-1)] Loss:  0.423188 Accuracy:  0.8000
# [Validation(27/-1)] Loss:  0.272679 Accuracy:  0.8810
# [Training(28/-1)] Loss:  0.305828 Accuracy:  0.8190
# [Validation(28/-1)] Loss:  0.120839 Accuracy:  0.9476
# [Training(29/-1)] Loss:  0.115429 Accuracy:  0.9571
# [Validation(29/-1)] Loss:  0.023383 Accuracy:  0.9952
# [Training(30/-1)] Loss:  0.044931 Accuracy:  0.9905
# [Validation(30/-1)] Loss:  0.000909 Accuracy:  1.0000
# [Training(31/-1)] Loss:  0.003178 Accuracy:  1.0000
# [Validation(31/-1)] Loss:  0.000081 Accuracy:  1.0000
# [Training(32/-1)] Loss:  0.000036 Accuracy:  1.0000
# [Validation(32/-1)] Loss:  0.000014 Accuracy:  1.0000
# [Training(33/-1)] Loss:  0.000001 Accuracy:  1.0000
# [Validation(33/-1)] Loss:  0.001879 Accuracy:  1.0000
# [Training(34/-1)] Loss:  0.007713 Accuracy:  1.0000
# [Validation(34/-1)] Loss:  0.009192 Accuracy:  1.0000
# [Training(35/-1)] Loss:  0.000157 Accuracy:  1.0000
# [Validation(35/-1)] Loss:  0.038381 Accuracy:  0.9762
# [Training(36/-1)] Loss:  0.001284 Accuracy:  1.0000
# [Validation(36/-1)] Loss:  0.072995 Accuracy:  0.9667
# [Training(37/-1)] Loss:  0.368223 Accuracy:  0.8762
# [Validation(37/-1)] Loss:  0.011676 Accuracy:  0.9905
# [Training(38/-1)] Loss:  0.014834 Accuracy:  0.9905
# [Validation(38/-1)] Loss:  0.000527 Accuracy:  1.0000
# [Training(39/-1)] Loss:  0.000089 Accuracy:  1.0000
# [Validation(39/-1)] Loss:  0.000057 Accuracy:  1.0000
# [Training(40/-1)] Loss:  0.000019 Accuracy:  1.0000
# [Validation(40/-1)] Loss:  0.000581 Accuracy:  1.0000
# [Training(41/-1)] Loss:  0.000036 Accuracy:  1.0000
# [Validation(41/-1)] Loss:  0.005224 Accuracy:  1.0000
# [Training(42/-1)] Loss:  0.023733 Accuracy:  0.9857
# [Validation(42/-1)] Loss:  0.002837 Accuracy:  1.0000
# [Training(43/-1)] Loss:  0.013992 Accuracy:  1.0000
# [Validation(43/-1)] Loss:  0.000419 Accuracy:  1.0000
# [Training(44/-1)] Loss:  0.000073 Accuracy:  1.0000
# [Validation(44/-1)] Loss:  0.000088 Accuracy:  1.0000
# [Training(45/-1)] Loss:  0.000040 Accuracy:  1.0000
# [Validation(45/-1)] Loss:  0.000029 Accuracy:  1.0000
# [Training(46/-1)] Loss:  0.000012 Accuracy:  1.0000
# [Validation(46/-1)] Loss:  0.000017 Accuracy:  1.0000
# [Training(47/-1)] Loss:  0.000098 Accuracy:  1.0000
# [Validation(47/-1)] Loss:  0.000016 Accuracy:  1.0000
# [Training(48/-1)] Loss:  0.000002 Accuracy:  1.0000
# [Validation(48/-1)] Loss:  0.000018 Accuracy:  1.0000
# [Training(49/-1)] Loss:  0.000036 Accuracy:  1.0000
# [Validation(49/-1)] Loss:  0.000021 Accuracy:  1.0000
# [Training(50/-1)] Loss:  0.000030 Accuracy:  1.0000
# [Validation(50/-1)] Loss:  0.000025 Accuracy:  1.0000
# [Training(51/-1)] Loss:  0.000056 Accuracy:  1.0000
# [Validation(51/-1)] Loss:  0.000029 Accuracy:  1.0000
# [Training(52/-1)] Loss:  0.000115 Accuracy:  1.0000
# [Validation(52/-1)] Loss:  0.000033 Accuracy:  1.0000
# [Training(53/-1)] Loss:  0.000054 Accuracy:  1.0000
# [Validation(53/-1)] Loss:  0.000038 Accuracy:  1.0000
# [Training(54/-1)] Loss:  0.000015 Accuracy:  1.0000
# [Validation(54/-1)] Loss:  0.000042 Accuracy:  1.0000
# [Training(55/-1)] Loss:  0.000035 Accuracy:  1.0000
# [Validation(55/-1)] Loss:  0.000047 Accuracy:  1.0000
# [Training(56/-1)] Loss:  0.002786 Accuracy:  1.0000
# [Validation(56/-1)] Loss:  0.000040 Accuracy:  1.0000
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmp434aim8z/model.weights
# [+] Training model for OpInfo(sid='/pivot_args_generator/Select@@2', gen_name='pivot_args_generator', op_type='Select', index=2, gen_group=None, uid=None, tags=None)
# [Training(1/-1)] Loss:  1.380446 Accuracy:  0.3000
# [Validation(1/-1)] Loss:  1.367806 Accuracy:  0.4000
# [Training(2/-1)] Loss:  1.367884 Accuracy:  0.3952
# [Validation(2/-1)] Loss:  1.357718 Accuracy:  0.3524
# [Training(3/-1)] Loss:  1.356975 Accuracy:  0.3619
# [Validation(3/-1)] Loss:  1.357183 Accuracy:  0.3524
# [Training(4/-1)] Loss:  1.358584 Accuracy:  0.3524
# [Validation(4/-1)] Loss:  1.351090 Accuracy:  0.3667
# [Training(5/-1)] Loss:  1.351131 Accuracy:  0.3714
# [Validation(5/-1)] Loss:  1.343541 Accuracy:  0.4143
# [Training(6/-1)] Loss:  1.343689 Accuracy:  0.3952
# [Validation(6/-1)] Loss:  1.342253 Accuracy:  0.4143
# [Training(7/-1)] Loss:  1.340800 Accuracy:  0.4143
# [Validation(7/-1)] Loss:  1.335549 Accuracy:  0.4143
# [Training(8/-1)] Loss:  1.335238 Accuracy:  0.4238
# [Validation(8/-1)] Loss:  1.319628 Accuracy:  0.4143
# [Training(9/-1)] Loss:  1.320374 Accuracy:  0.4143
# [Validation(9/-1)] Loss:  1.311299 Accuracy:  0.4143
# [Training(10/-1)] Loss:  1.311027 Accuracy:  0.4143
# [Validation(10/-1)] Loss:  1.292932 Accuracy:  0.4143
# [Training(11/-1)] Loss:  1.295302 Accuracy:  0.4143
# [Validation(11/-1)] Loss:  1.293172 Accuracy:  0.4143
# [Training(12/-1)] Loss:  1.290017 Accuracy:  0.4143
# [Validation(12/-1)] Loss:  1.270803 Accuracy:  0.4143
# [Training(13/-1)] Loss:  1.267922 Accuracy:  0.4143
# [Validation(13/-1)] Loss:  1.250649 Accuracy:  0.4143
# [Training(14/-1)] Loss:  1.243911 Accuracy:  0.4190
# [Validation(14/-1)] Loss:  1.264464 Accuracy:  0.4143
# [Training(15/-1)] Loss:  1.251503 Accuracy:  0.4190
# [Validation(15/-1)] Loss:  1.259091 Accuracy:  0.2571
# [Training(16/-1)] Loss:  1.361320 Accuracy:  0.2571
# [Validation(16/-1)] Loss:  1.233353 Accuracy:  0.4429
# [Training(17/-1)] Loss:  1.261789 Accuracy:  0.5048
# [Validation(17/-1)] Loss:  1.241260 Accuracy:  0.4905
# [Training(18/-1)] Loss:  1.228849 Accuracy:  0.4857
# [Validation(18/-1)] Loss:  1.212222 Accuracy:  0.4857
# [Training(19/-1)] Loss:  1.214649 Accuracy:  0.4714
# [Validation(19/-1)] Loss:  1.220903 Accuracy:  0.4381
# [Training(20/-1)] Loss:  1.213891 Accuracy:  0.4714
# [Validation(20/-1)] Loss:  1.239020 Accuracy:  0.2571
# [Training(21/-1)] Loss:  1.268777 Accuracy:  0.2571
# [Validation(21/-1)] Loss:  1.200675 Accuracy:  0.5238
# [Training(22/-1)] Loss:  1.204381 Accuracy:  0.5619
# [Validation(22/-1)] Loss:  1.220874 Accuracy:  0.5524
# [Training(23/-1)] Loss:  1.272282 Accuracy:  0.5429
# [Validation(23/-1)] Loss:  1.215011 Accuracy:  0.5857
# [Training(24/-1)] Loss:  1.214239 Accuracy:  0.5762
# [Validation(24/-1)] Loss:  1.196992 Accuracy:  0.5857
# [Training(25/-1)] Loss:  1.196399 Accuracy:  0.5810
# [Validation(25/-1)] Loss:  1.183847 Accuracy:  0.5857
# [Training(26/-1)] Loss:  1.180562 Accuracy:  0.6095
# [Validation(26/-1)] Loss:  1.185606 Accuracy:  0.6143
# [Training(27/-1)] Loss:  1.184232 Accuracy:  0.6143
# [Validation(27/-1)] Loss:  1.166428 Accuracy:  0.5095
# [Training(28/-1)] Loss:  1.163915 Accuracy:  0.5667
# [Validation(28/-1)] Loss:  1.117358 Accuracy:  0.5762
# [Training(29/-1)] Loss:  1.089619 Accuracy:  0.6333
# [Validation(29/-1)] Loss:  1.031602 Accuracy:  0.6714
# [Training(30/-1)] Loss:  1.022627 Accuracy:  0.6333
# [Validation(30/-1)] Loss:  0.915918 Accuracy:  0.6476
# [Training(31/-1)] Loss:  0.916585 Accuracy:  0.6143
# [Validation(31/-1)] Loss:  0.846789 Accuracy:  0.6333
# [Training(32/-1)] Loss:  0.828931 Accuracy:  0.6667
# [Validation(32/-1)] Loss:  0.814213 Accuracy:  0.6143
# [Training(33/-1)] Loss:  0.778272 Accuracy:  0.6238
# [Validation(33/-1)] Loss:  0.872615 Accuracy:  0.6952
# [Training(34/-1)] Loss:  0.878598 Accuracy:  0.6857
# [Validation(34/-1)] Loss:  0.962643 Accuracy:  0.6762
# [Training(35/-1)] Loss:  1.068282 Accuracy:  0.6048
# [Validation(35/-1)] Loss:  0.765454 Accuracy:  0.6952
# [Training(36/-1)] Loss:  0.800878 Accuracy:  0.7095
# [Validation(36/-1)] Loss:  0.690612 Accuracy:  0.7143
# [Training(37/-1)] Loss:  0.645474 Accuracy:  0.7190
# [Validation(37/-1)] Loss:  0.626451 Accuracy:  0.7476
# [Training(38/-1)] Loss:  0.638992 Accuracy:  0.7429
# [Validation(38/-1)] Loss:  0.631136 Accuracy:  0.8000
# [Training(39/-1)] Loss:  0.610645 Accuracy:  0.8000
# [Validation(39/-1)] Loss:  0.645313 Accuracy:  0.7905
# [Training(40/-1)] Loss:  0.757362 Accuracy:  0.5952
# [Validation(40/-1)] Loss:  0.612938 Accuracy:  0.7667
# [Training(41/-1)] Loss:  0.613740 Accuracy:  0.7571
# [Validation(41/-1)] Loss:  0.632336 Accuracy:  0.7571
# [Training(42/-1)] Loss:  0.615557 Accuracy:  0.7714
# [Validation(42/-1)] Loss:  0.625642 Accuracy:  0.7619
# [Training(43/-1)] Loss:  0.608548 Accuracy:  0.7905
# [Validation(43/-1)] Loss:  0.559955 Accuracy:  0.7952
# [Training(44/-1)] Loss:  0.605895 Accuracy:  0.7571
# [Validation(44/-1)] Loss:  0.483077 Accuracy:  0.7952
# [Training(45/-1)] Loss:  0.486602 Accuracy:  0.8048
# [Validation(45/-1)] Loss:  0.480956 Accuracy:  0.8238
# [Training(46/-1)] Loss:  0.544166 Accuracy:  0.8000
# [Validation(46/-1)] Loss:  0.423331 Accuracy:  0.8476
# [Training(47/-1)] Loss:  0.483626 Accuracy:  0.8143
# [Validation(47/-1)] Loss:  0.405197 Accuracy:  0.8286
# [Training(48/-1)] Loss:  0.450645 Accuracy:  0.8048
# [Validation(48/-1)] Loss:  0.440858 Accuracy:  0.8333
# [Training(49/-1)] Loss:  0.399037 Accuracy:  0.8381
# [Validation(49/-1)] Loss:  0.363879 Accuracy:  0.8524
# [Training(50/-1)] Loss:  0.436502 Accuracy:  0.8429
# [Validation(50/-1)] Loss:  0.282461 Accuracy:  0.9048
# [Training(51/-1)] Loss:  0.326904 Accuracy:  0.8667
# [Validation(51/-1)] Loss:  0.352816 Accuracy:  0.8429
# [Training(52/-1)] Loss:  0.263378 Accuracy:  0.8810
# [Validation(52/-1)] Loss:  0.244980 Accuracy:  0.9619
# [Training(53/-1)] Loss:  0.236972 Accuracy:  0.9048
# [Validation(53/-1)] Loss:  0.198586 Accuracy:  0.9190
# [Training(54/-1)] Loss:  0.181571 Accuracy:  0.9190
# [Validation(54/-1)] Loss:  0.233945 Accuracy:  0.9048
# [Training(55/-1)] Loss:  0.218674 Accuracy:  0.9190
# [Validation(55/-1)] Loss:  0.200878 Accuracy:  0.9238
# [Training(56/-1)] Loss:  0.146658 Accuracy:  0.9476
# [Validation(56/-1)] Loss:  0.111052 Accuracy:  0.9571
# [Training(57/-1)] Loss:  0.112739 Accuracy:  0.9571
# [Validation(57/-1)] Loss:  0.055271 Accuracy:  0.9810
# [Training(58/-1)] Loss:  0.070079 Accuracy:  0.9810
# [Validation(58/-1)] Loss:  0.085116 Accuracy:  1.0000
# [Training(59/-1)] Loss:  0.103409 Accuracy:  1.0000
# [Validation(59/-1)] Loss:  0.034904 Accuracy:  1.0000
# [Training(60/-1)] Loss:  0.018104 Accuracy:  1.0000
# [Validation(60/-1)] Loss:  0.015000 Accuracy:  1.0000
# [Training(61/-1)] Loss:  0.034610 Accuracy:  1.0000
# [Validation(61/-1)] Loss:  0.010404 Accuracy:  1.0000
# [Training(62/-1)] Loss:  0.004905 Accuracy:  1.0000
# [Validation(62/-1)] Loss:  0.022955 Accuracy:  1.0000
# [Training(63/-1)] Loss:  0.026258 Accuracy:  0.9905
# [Validation(63/-1)] Loss:  0.021822 Accuracy:  0.9952
# [Training(64/-1)] Loss:  0.011660 Accuracy:  1.0000
# [Validation(64/-1)] Loss:  0.009112 Accuracy:  1.0000
# [Training(65/-1)] Loss:  0.015965 Accuracy:  1.0000
# [Validation(65/-1)] Loss:  0.001008 Accuracy:  1.0000
# [Training(66/-1)] Loss:  0.010697 Accuracy:  1.0000
# [Validation(66/-1)] Loss:  0.000546 Accuracy:  1.0000
# [Training(67/-1)] Loss:  0.002213 Accuracy:  1.0000
# [Validation(67/-1)] Loss:  0.001512 Accuracy:  1.0000
# [Training(68/-1)] Loss:  0.002928 Accuracy:  1.0000
# [Validation(68/-1)] Loss:  0.004856 Accuracy:  1.0000
# [Training(69/-1)] Loss:  0.002945 Accuracy:  1.0000
# [Validation(69/-1)] Loss:  0.012210 Accuracy:  0.9905
# [Training(70/-1)] Loss:  0.064633 Accuracy:  0.9571
# [Validation(70/-1)] Loss:  0.000718 Accuracy:  1.0000
# [Training(71/-1)] Loss:  0.001256 Accuracy:  1.0000
# [Validation(71/-1)] Loss:  0.000060 Accuracy:  1.0000
# [Training(72/-1)] Loss:  0.000036 Accuracy:  1.0000
# [Validation(72/-1)] Loss:  0.000024 Accuracy:  1.0000
# [Training(73/-1)] Loss:  0.000022 Accuracy:  1.0000
# [Validation(73/-1)] Loss:  0.000127 Accuracy:  1.0000
# [Training(74/-1)] Loss:  0.000357 Accuracy:  1.0000
# [Validation(74/-1)] Loss:  0.001068 Accuracy:  1.0000
# [Training(75/-1)] Loss:  0.081945 Accuracy:  0.9619
# [Validation(75/-1)] Loss:  0.000034 Accuracy:  1.0000
# [Training(76/-1)] Loss:  0.000171 Accuracy:  1.0000
# [Validation(76/-1)] Loss:  0.000012 Accuracy:  1.0000
# [Training(77/-1)] Loss:  0.000099 Accuracy:  1.0000
# [Validation(77/-1)] Loss:  0.000033 Accuracy:  1.0000
# [Training(78/-1)] Loss:  0.000012 Accuracy:  1.0000
# [Validation(78/-1)] Loss:  0.000164 Accuracy:  1.0000
# [Training(79/-1)] Loss:  0.000294 Accuracy:  1.0000
# [Validation(79/-1)] Loss:  0.000929 Accuracy:  1.0000
# [Training(80/-1)] Loss:  0.011663 Accuracy:  0.9905
# [Validation(80/-1)] Loss:  0.000891 Accuracy:  1.0000
# [Training(81/-1)] Loss:  0.000062 Accuracy:  1.0000
# [Validation(81/-1)] Loss:  0.000978 Accuracy:  1.0000
# [Training(82/-1)] Loss:  0.001787 Accuracy:  1.0000
# [Validation(82/-1)] Loss:  0.000770 Accuracy:  1.0000
# [Training(83/-1)] Loss:  0.000012 Accuracy:  1.0000
# [Validation(83/-1)] Loss:  0.000614 Accuracy:  1.0000
# [Training(84/-1)] Loss:  0.000030 Accuracy:  1.0000
# [Validation(84/-1)] Loss:  0.000494 Accuracy:  1.0000
# [Training(85/-1)] Loss:  0.023457 Accuracy:  0.9905
# [Validation(85/-1)] Loss:  0.000021 Accuracy:  1.0000
# [Training(86/-1)] Loss:  0.001388 Accuracy:  1.0000
# [Validation(86/-1)] Loss:  0.000006 Accuracy:  1.0000
# [Training(87/-1)] Loss:  0.000010 Accuracy:  1.0000
# [Validation(87/-1)] Loss:  0.000008 Accuracy:  1.0000
# [Training(88/-1)] Loss:  0.000005 Accuracy:  1.0000
# [Validation(88/-1)] Loss:  0.000026 Accuracy:  1.0000
# [Training(89/-1)] Loss:  0.000021 Accuracy:  1.0000
# [Validation(89/-1)] Loss:  0.000365 Accuracy:  1.0000
# [Training(90/-1)] Loss:  0.000860 Accuracy:  1.0000
# [Validation(90/-1)] Loss:  0.003610 Accuracy:  1.0000
# [Training(91/-1)] Loss:  0.006665 Accuracy:  0.9952
# [Validation(91/-1)] Loss:  0.006320 Accuracy:  1.0000
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmpt2vwsg4i/model.weights
# [+] Training model for OpInfo(sid='/pivot_args_generator/Select@@3', gen_name='pivot_args_generator', op_type='Select', index=3, gen_group=None, uid=None, tags=None)
# [Training(1/-1)] Loss:  1.650651 Accuracy:  0.1667
# [Validation(1/-1)] Loss:  1.653702 Accuracy:  0.1952
# [Training(2/-1)] Loss:  1.653650 Accuracy:  0.1952
# [Validation(2/-1)] Loss:  1.652600 Accuracy:  0.1952
# [Training(3/-1)] Loss:  1.652591 Accuracy:  0.1952
# [Validation(3/-1)] Loss:  1.652664 Accuracy:  0.1810
# [Training(4/-1)] Loss:  1.652665 Accuracy:  0.1857
# [Validation(4/-1)] Loss:  1.652668 Accuracy:  0.3190
# [Training(5/-1)] Loss:  1.652669 Accuracy:  0.2238
# [Validation(5/-1)] Loss:  1.652645 Accuracy:  0.3095
# [Training(6/-1)] Loss:  1.652621 Accuracy:  0.2095
# [Validation(6/-1)] Loss:  1.652637 Accuracy:  0.2524
# [Training(7/-1)] Loss:  1.652626 Accuracy:  0.2524
# [Validation(7/-1)] Loss:  1.652598 Accuracy:  0.1952
# [Training(8/-1)] Loss:  1.652587 Accuracy:  0.1952
# [Validation(8/-1)] Loss:  1.652548 Accuracy:  0.1952
# [Training(9/-1)] Loss:  1.652546 Accuracy:  0.1952
# [Validation(9/-1)] Loss:  1.652451 Accuracy:  0.1952
# [Training(10/-1)] Loss:  1.652455 Accuracy:  0.1952
# [Validation(10/-1)] Loss:  1.652336 Accuracy:  0.1952
# [Training(11/-1)] Loss:  1.652345 Accuracy:  0.1952
# [Validation(11/-1)] Loss:  1.652181 Accuracy:  0.1952
# [Training(12/-1)] Loss:  1.652168 Accuracy:  0.1952
# [Validation(12/-1)] Loss:  1.652018 Accuracy:  0.1952
# [Training(13/-1)] Loss:  1.651994 Accuracy:  0.1952
# [Validation(13/-1)] Loss:  1.651779 Accuracy:  0.1952
# [Training(14/-1)] Loss:  1.651769 Accuracy:  0.1952
# [Validation(14/-1)] Loss:  1.651530 Accuracy:  0.1952
# [Training(15/-1)] Loss:  1.651528 Accuracy:  0.1952
# [Validation(15/-1)] Loss:  1.651150 Accuracy:  0.1952
# [Training(16/-1)] Loss:  1.651168 Accuracy:  0.1952
# [Validation(16/-1)] Loss:  1.650662 Accuracy:  0.1952
# [Training(17/-1)] Loss:  1.650613 Accuracy:  0.1952
# [Validation(17/-1)] Loss:  1.649968 Accuracy:  0.1952
# [Training(18/-1)] Loss:  1.649927 Accuracy:  0.1952
# [Validation(18/-1)] Loss:  1.649050 Accuracy:  0.1952
# [Training(19/-1)] Loss:  1.649070 Accuracy:  0.1952
# [Validation(19/-1)] Loss:  1.647861 Accuracy:  0.1952
# [Training(20/-1)] Loss:  1.647771 Accuracy:  0.1952
# [Validation(20/-1)] Loss:  1.646385 Accuracy:  0.1952
# [Training(21/-1)] Loss:  1.646386 Accuracy:  0.1952
# [Validation(21/-1)] Loss:  1.644620 Accuracy:  0.1952
# [Training(22/-1)] Loss:  1.644674 Accuracy:  0.1952
# [Validation(22/-1)] Loss:  1.642973 Accuracy:  0.1952
# [Training(23/-1)] Loss:  1.643021 Accuracy:  0.1952
# [Validation(23/-1)] Loss:  1.641469 Accuracy:  0.1952
# [Training(24/-1)] Loss:  1.641481 Accuracy:  0.1952
# [Validation(24/-1)] Loss:  1.640292 Accuracy:  0.1952
# [Training(25/-1)] Loss:  1.640251 Accuracy:  0.1952
# [Validation(25/-1)] Loss:  1.639345 Accuracy:  0.1952
# [Training(26/-1)] Loss:  1.639185 Accuracy:  0.1952
# [Validation(26/-1)] Loss:  1.638201 Accuracy:  0.1952
# [Training(27/-1)] Loss:  1.638204 Accuracy:  0.1952
# [Validation(27/-1)] Loss:  1.636575 Accuracy:  0.1952
# [Training(28/-1)] Loss:  1.636733 Accuracy:  0.1952
# [Validation(28/-1)] Loss:  1.630980 Accuracy:  0.1952
# [Training(29/-1)] Loss:  1.630686 Accuracy:  0.1952
# [Validation(29/-1)] Loss:  1.906228 Accuracy:  0.1952
# [Training(30/-1)] Loss:  1.896607 Accuracy:  0.1952
# [Validation(30/-1)] Loss:  1.633417 Accuracy:  0.1952
# [Training(31/-1)] Loss:  1.633373 Accuracy:  0.1952
# [Validation(31/-1)] Loss:  1.634489 Accuracy:  0.1952
# [Training(32/-1)] Loss:  1.634466 Accuracy:  0.1952
# [Validation(32/-1)] Loss:  1.632530 Accuracy:  0.1952
# [Training(33/-1)] Loss:  1.632679 Accuracy:  0.1952
# [Validation(33/-1)] Loss:  1.632146 Accuracy:  0.1952
# [Training(34/-1)] Loss:  1.632344 Accuracy:  0.1952
# [Validation(34/-1)] Loss:  1.634044 Accuracy:  0.1952
# [Training(35/-1)] Loss:  1.634069 Accuracy:  0.1952
# [Validation(35/-1)] Loss:  1.633939 Accuracy:  0.1952
# [Training(36/-1)] Loss:  1.633854 Accuracy:  0.1952
# [Validation(36/-1)] Loss:  1.633387 Accuracy:  0.1952
# [Training(37/-1)] Loss:  1.633476 Accuracy:  0.1952
# [Validation(37/-1)] Loss:  1.632965 Accuracy:  0.1952
# [Training(38/-1)] Loss:  1.633099 Accuracy:  0.1952
# [Validation(38/-1)] Loss:  1.632413 Accuracy:  0.1952
# [Training(39/-1)] Loss:  1.632422 Accuracy:  0.1952
# [Validation(39/-1)] Loss:  1.631762 Accuracy:  0.1952
# [Training(40/-1)] Loss:  1.631866 Accuracy:  0.1952
# [Validation(40/-1)] Loss:  1.631053 Accuracy:  0.1952
# [Training(41/-1)] Loss:  1.631062 Accuracy:  0.1952
# [Validation(41/-1)] Loss:  1.630128 Accuracy:  0.1952
# [Training(42/-1)] Loss:  1.629877 Accuracy:  0.1952
# [Validation(42/-1)] Loss:  1.628853 Accuracy:  0.1952
# [Training(43/-1)] Loss:  1.628705 Accuracy:  0.1952
# [Validation(43/-1)] Loss:  1.627886 Accuracy:  0.1952
# [Training(44/-1)] Loss:  1.627778 Accuracy:  0.1952
# [Validation(44/-1)] Loss:  1.626636 Accuracy:  0.1952
# [Training(45/-1)] Loss:  1.626645 Accuracy:  0.1952
# [Validation(45/-1)] Loss:  1.626040 Accuracy:  0.1952
# [Training(46/-1)] Loss:  1.626200 Accuracy:  0.1952
# [Validation(46/-1)] Loss:  1.624725 Accuracy:  0.1952
# [Training(47/-1)] Loss:  1.624814 Accuracy:  0.1952
# [Validation(47/-1)] Loss:  1.624101 Accuracy:  0.1952
# [Training(48/-1)] Loss:  1.624196 Accuracy:  0.1952
# [Validation(48/-1)] Loss:  1.622626 Accuracy:  0.1952
# [Training(49/-1)] Loss:  1.622772 Accuracy:  0.1952
# [Validation(49/-1)] Loss:  1.621603 Accuracy:  0.1952
# [Training(50/-1)] Loss:  1.621755 Accuracy:  0.1952
# [Validation(50/-1)] Loss:  1.620609 Accuracy:  0.1952
# [Training(51/-1)] Loss:  1.620604 Accuracy:  0.1952
# [Validation(51/-1)] Loss:  1.619086 Accuracy:  0.1952
# [Training(52/-1)] Loss:  1.619110 Accuracy:  0.1952
# [Validation(52/-1)] Loss:  1.618519 Accuracy:  0.1952
# [Training(53/-1)] Loss:  1.618437 Accuracy:  0.1952
# [Validation(53/-1)] Loss:  1.616652 Accuracy:  0.1952
# [Training(54/-1)] Loss:  1.616899 Accuracy:  0.1952
# [Validation(54/-1)] Loss:  1.616060 Accuracy:  0.1952
# [Training(55/-1)] Loss:  1.616063 Accuracy:  0.1952
# [Validation(55/-1)] Loss:  1.614294 Accuracy:  0.1952
# [Training(56/-1)] Loss:  1.614286 Accuracy:  0.1952
# [Validation(56/-1)] Loss:  1.612817 Accuracy:  0.1952
# [Training(57/-1)] Loss:  1.613060 Accuracy:  0.1952
# [Validation(57/-1)] Loss:  1.611383 Accuracy:  0.1952
# [Training(58/-1)] Loss:  1.611530 Accuracy:  0.1952
# [Validation(58/-1)] Loss:  1.610145 Accuracy:  0.1952
# [Training(59/-1)] Loss:  1.610260 Accuracy:  0.1952
# [Validation(59/-1)] Loss:  1.608476 Accuracy:  0.1952
# [Training(60/-1)] Loss:  1.608950 Accuracy:  0.1952
# [Validation(60/-1)] Loss:  1.607328 Accuracy:  0.1952
# [Training(61/-1)] Loss:  1.607275 Accuracy:  0.1952
# [Validation(61/-1)] Loss:  1.604916 Accuracy:  0.1952
# [Training(62/-1)] Loss:  1.605056 Accuracy:  0.1952
# [Validation(62/-1)] Loss:  1.604677 Accuracy:  0.1952
# [Training(63/-1)] Loss:  1.605045 Accuracy:  0.1952
# [Validation(63/-1)] Loss:  1.601988 Accuracy:  0.1952
# [Training(64/-1)] Loss:  1.601998 Accuracy:  0.1952
# [Validation(64/-1)] Loss:  1.599113 Accuracy:  0.1952
# [Training(65/-1)] Loss:  1.598782 Accuracy:  0.1952
# [Validation(65/-1)] Loss:  1.597538 Accuracy:  0.1952
# [Training(66/-1)] Loss:  1.596732 Accuracy:  0.1952
# [Validation(66/-1)] Loss:  1.595752 Accuracy:  0.1952
# [Training(67/-1)] Loss:  1.595921 Accuracy:  0.1952
# [Validation(67/-1)] Loss:  1.593209 Accuracy:  0.1952
# [Training(68/-1)] Loss:  1.594520 Accuracy:  0.1952
# [Validation(68/-1)] Loss:  1.589546 Accuracy:  0.1952
# [Training(69/-1)] Loss:  1.589965 Accuracy:  0.1952
# [Validation(69/-1)] Loss:  1.591088 Accuracy:  0.2714
# [Training(70/-1)] Loss:  1.592018 Accuracy:  0.1952
# [Validation(70/-1)] Loss:  1.583659 Accuracy:  0.1952
# [Training(71/-1)] Loss:  1.586152 Accuracy:  0.1952
# [Validation(71/-1)] Loss:  1.582224 Accuracy:  0.1952
# [Training(72/-1)] Loss:  1.582674 Accuracy:  0.1952
# [Validation(72/-1)] Loss:  1.583794 Accuracy:  0.1952
# [Training(73/-1)] Loss:  1.582621 Accuracy:  0.1952
# [Validation(73/-1)] Loss:  1.580244 Accuracy:  0.1952
# [Training(74/-1)] Loss:  1.581605 Accuracy:  0.1952
# [Validation(74/-1)] Loss:  1.572205 Accuracy:  0.1952
# [Training(75/-1)] Loss:  1.571792 Accuracy:  0.1952
# [Validation(75/-1)] Loss:  1.576264 Accuracy:  0.1952
# [Training(76/-1)] Loss:  1.577889 Accuracy:  0.1952
# [Validation(76/-1)] Loss:  1.563805 Accuracy:  0.1952
# [Training(77/-1)] Loss:  1.563632 Accuracy:  0.1952
# [Validation(77/-1)] Loss:  1.559921 Accuracy:  0.1952
# [Training(78/-1)] Loss:  1.560226 Accuracy:  0.1952
# [Validation(78/-1)] Loss:  1.556625 Accuracy:  0.1952
# [Training(79/-1)] Loss:  1.555783 Accuracy:  0.1952
# [Validation(79/-1)] Loss:  1.554919 Accuracy:  0.1952
# [Training(80/-1)] Loss:  1.554548 Accuracy:  0.1952
# [Validation(80/-1)] Loss:  1.548389 Accuracy:  0.1952
# [Training(81/-1)] Loss:  1.547685 Accuracy:  0.1952
# [Validation(81/-1)] Loss:  1.543307 Accuracy:  0.1952
# [Training(82/-1)] Loss:  1.543500 Accuracy:  0.1952
# [Validation(82/-1)] Loss:  1.536313 Accuracy:  0.1952
# [Training(83/-1)] Loss:  1.537131 Accuracy:  0.1952
# [Validation(83/-1)] Loss:  1.529290 Accuracy:  0.1952
# [Training(84/-1)] Loss:  1.529503 Accuracy:  0.1952
# [Validation(84/-1)] Loss:  1.526730 Accuracy:  0.2143
# [Training(85/-1)] Loss:  1.526695 Accuracy:  0.2143
# [Validation(85/-1)] Loss:  1.522706 Accuracy:  0.2143
# [Training(86/-1)] Loss:  1.521967 Accuracy:  0.2333
# [Validation(86/-1)] Loss:  1.515205 Accuracy:  0.2286
# [Training(87/-1)] Loss:  1.516016 Accuracy:  0.2190
# [Validation(87/-1)] Loss:  1.521803 Accuracy:  0.2381
# [Training(88/-1)] Loss:  1.523242 Accuracy:  0.2524
# [Validation(88/-1)] Loss:  1.507036 Accuracy:  0.2381
# [Training(89/-1)] Loss:  1.506829 Accuracy:  0.2381
# [Validation(89/-1)] Loss:  1.503114 Accuracy:  0.2714
# [Training(90/-1)] Loss:  1.506070 Accuracy:  0.2667
# [Validation(90/-1)] Loss:  1.490050 Accuracy:  0.3143
# [Training(91/-1)] Loss:  1.492723 Accuracy:  0.3571
# [Validation(91/-1)] Loss:  1.474077 Accuracy:  0.4762
# [Training(92/-1)] Loss:  1.475219 Accuracy:  0.2619
# [Validation(92/-1)] Loss:  1.459166 Accuracy:  0.5429
# [Training(93/-1)] Loss:  1.456201 Accuracy:  0.5524
# [Validation(93/-1)] Loss:  1.431848 Accuracy:  0.6476
# [Training(94/-1)] Loss:  1.435290 Accuracy:  0.6905
# [Validation(94/-1)] Loss:  1.371061 Accuracy:  0.6524
# [Training(95/-1)] Loss:  1.390752 Accuracy:  0.6857
# [Validation(95/-1)] Loss:  1.340143 Accuracy:  0.6524
# [Training(96/-1)] Loss:  1.321922 Accuracy:  0.6095
# [Validation(96/-1)] Loss:  1.150564 Accuracy:  0.7429
# [Training(97/-1)] Loss:  1.138905 Accuracy:  0.7476
# [Validation(97/-1)] Loss:  1.225747 Accuracy:  0.4524
# [Training(98/-1)] Loss:  1.166749 Accuracy:  0.5667
# [Validation(98/-1)] Loss:  0.901048 Accuracy:  0.6952
# [Training(99/-1)] Loss:  0.913620 Accuracy:  0.6905
# [Validation(99/-1)] Loss:  0.879998 Accuracy:  0.6476
# [Training(100/-1)] Loss:  0.859098 Accuracy:  0.6762
# [Validation(100/-1)] Loss:  0.742485 Accuracy:  0.6857
# [Training(101/-1)] Loss:  0.836607 Accuracy:  0.6714
# [Validation(101/-1)] Loss:  1.124747 Accuracy:  0.4762
# [Training(102/-1)] Loss:  1.072236 Accuracy:  0.4905
# [Validation(102/-1)] Loss:  0.732798 Accuracy:  0.6000
# [Training(103/-1)] Loss:  0.681829 Accuracy:  0.5619
# [Validation(103/-1)] Loss:  0.670140 Accuracy:  0.5619
# [Training(104/-1)] Loss:  0.660020 Accuracy:  0.5190
# [Validation(104/-1)] Loss:  0.670746 Accuracy:  0.5905
# [Training(105/-1)] Loss:  0.671254 Accuracy:  0.5952
# [Validation(105/-1)] Loss:  0.656172 Accuracy:  0.5571
# [Training(106/-1)] Loss:  0.696456 Accuracy:  0.4619
# [Validation(106/-1)] Loss:  0.606122 Accuracy:  0.5333
# [Training(107/-1)] Loss:  0.619424 Accuracy:  0.5476
# [Validation(107/-1)] Loss:  0.599466 Accuracy:  0.5000
# [Training(108/-1)] Loss:  0.585497 Accuracy:  0.4810
# [Validation(108/-1)] Loss:  0.612321 Accuracy:  0.5000
# [Training(109/-1)] Loss:  0.666891 Accuracy:  0.5333
# [Validation(109/-1)] Loss:  0.568560 Accuracy:  0.4714
# [Training(110/-1)] Loss:  0.633456 Accuracy:  0.4524
# [Validation(110/-1)] Loss:  0.552580 Accuracy:  0.6429
# [Training(111/-1)] Loss:  0.557081 Accuracy:  0.6095
# [Validation(111/-1)] Loss:  0.550510 Accuracy:  0.6571
# [Training(112/-1)] Loss:  0.558556 Accuracy:  0.6857
# [Validation(112/-1)] Loss:  0.542992 Accuracy:  0.6429
# [Training(113/-1)] Loss:  0.542492 Accuracy:  0.6619
# [Validation(113/-1)] Loss:  0.525751 Accuracy:  0.6524
# [Training(114/-1)] Loss:  0.529430 Accuracy:  0.6000
# [Validation(114/-1)] Loss:  0.513113 Accuracy:  0.6048
# [Training(115/-1)] Loss:  0.513358 Accuracy:  0.6190
# [Validation(115/-1)] Loss:  0.506605 Accuracy:  0.4714
# [Training(116/-1)] Loss:  0.504701 Accuracy:  0.5143
# [Validation(116/-1)] Loss:  0.497624 Accuracy:  0.5571
# [Training(117/-1)] Loss:  0.494212 Accuracy:  0.6048
# [Validation(117/-1)] Loss:  0.484233 Accuracy:  0.6524
# [Training(118/-1)] Loss:  0.474413 Accuracy:  0.6714
# [Validation(118/-1)] Loss:  0.431549 Accuracy:  0.6905
# [Training(119/-1)] Loss:  0.369401 Accuracy:  0.8238
# [Validation(119/-1)] Loss:  0.377360 Accuracy:  0.7762
# [Training(120/-1)] Loss:  0.364665 Accuracy:  0.8238
# [Validation(120/-1)] Loss:  0.348881 Accuracy:  0.8238
# [Training(121/-1)] Loss:  0.359952 Accuracy:  0.8238
# [Validation(121/-1)] Loss:  0.551418 Accuracy:  0.7810
# [Training(122/-1)] Loss:  0.577803 Accuracy:  0.7905
# [Validation(122/-1)] Loss:  0.315929 Accuracy:  0.8238
# [Training(123/-1)] Loss:  0.334428 Accuracy:  0.8619
# [Validation(123/-1)] Loss:  0.310282 Accuracy:  0.8190
# [Training(124/-1)] Loss:  0.409814 Accuracy:  0.7762
# [Validation(124/-1)] Loss:  0.384062 Accuracy:  0.7381
# [Training(125/-1)] Loss:  0.412662 Accuracy:  0.7667
# [Validation(125/-1)] Loss:  0.445571 Accuracy:  0.7381
# [Training(126/-1)] Loss:  0.510021 Accuracy:  0.7619
# [Validation(126/-1)] Loss:  0.395923 Accuracy:  0.7476
# [Training(127/-1)] Loss:  0.449077 Accuracy:  0.7952
# [Validation(127/-1)] Loss:  0.329582 Accuracy:  0.8762
# [Training(128/-1)] Loss:  0.328969 Accuracy:  0.8762
# [Validation(128/-1)] Loss:  0.312201 Accuracy:  0.9524
# [Training(129/-1)] Loss:  0.298777 Accuracy:  0.9667
# [Validation(129/-1)] Loss:  0.265573 Accuracy:  0.9714
# [Training(130/-1)] Loss:  0.246965 Accuracy:  0.9810
# [Validation(130/-1)] Loss:  0.215789 Accuracy:  0.9810
# [Training(131/-1)] Loss:  0.249799 Accuracy:  0.9571
# [Validation(131/-1)] Loss:  0.354866 Accuracy:  0.8476
# [Training(132/-1)] Loss:  0.833373 Accuracy:  0.6000
# [Validation(132/-1)] Loss:  0.238533 Accuracy:  0.9143
# [Training(133/-1)] Loss:  0.198684 Accuracy:  0.9810
# [Validation(133/-1)] Loss:  0.222473 Accuracy:  0.9714
# [Training(134/-1)] Loss:  0.193667 Accuracy:  0.9810
# [Validation(134/-1)] Loss:  0.214424 Accuracy:  0.9619
# [Training(135/-1)] Loss:  0.205019 Accuracy:  0.9667
# [Validation(135/-1)] Loss:  0.184119 Accuracy:  0.9667
# [Training(136/-1)] Loss:  0.203620 Accuracy:  0.9714
# [Validation(136/-1)] Loss:  0.177276 Accuracy:  0.9952
# [Training(137/-1)] Loss:  0.193541 Accuracy:  0.9905
# [Validation(137/-1)] Loss:  0.165426 Accuracy:  1.0000
# [Training(138/-1)] Loss:  0.172205 Accuracy:  1.0000
# [Validation(138/-1)] Loss:  0.159408 Accuracy:  1.0000
# [Training(139/-1)] Loss:  0.170257 Accuracy:  0.9810
# [Validation(139/-1)] Loss:  0.159889 Accuracy:  1.0000
# [Training(140/-1)] Loss:  0.195111 Accuracy:  1.0000
# [Validation(140/-1)] Loss:  0.148935 Accuracy:  1.0000
# [Training(141/-1)] Loss:  0.164960 Accuracy:  1.0000
# [Validation(141/-1)] Loss:  0.129608 Accuracy:  1.0000
# [Training(142/-1)] Loss:  0.155401 Accuracy:  1.0000
# [Validation(142/-1)] Loss:  0.110349 Accuracy:  1.0000
# [Training(143/-1)] Loss:  0.115003 Accuracy:  1.0000
# [Validation(143/-1)] Loss:  0.096985 Accuracy:  1.0000
# [Training(144/-1)] Loss:  0.105532 Accuracy:  0.9905
# [Validation(144/-1)] Loss:  0.095511 Accuracy:  0.9905
# [Training(145/-1)] Loss:  0.089297 Accuracy:  0.9905
# [Validation(145/-1)] Loss:  0.089943 Accuracy:  0.9905
# [Training(146/-1)] Loss:  0.094073 Accuracy:  0.9905
# [Validation(146/-1)] Loss:  0.084996 Accuracy:  1.0000
# [Training(147/-1)] Loss:  0.243324 Accuracy:  0.9952
# [Validation(147/-1)] Loss:  0.079053 Accuracy:  1.0000
# [Training(148/-1)] Loss:  0.071805 Accuracy:  0.9905
# [Validation(148/-1)] Loss:  0.074853 Accuracy:  1.0000
# [Training(149/-1)] Loss:  0.177946 Accuracy:  1.0000
# [Validation(149/-1)] Loss:  0.060934 Accuracy:  1.0000
# [Training(150/-1)] Loss:  0.072330 Accuracy:  0.9952
# [Validation(150/-1)] Loss:  0.051260 Accuracy:  1.0000
# [Training(151/-1)] Loss:  0.110558 Accuracy:  1.0000
# [Validation(151/-1)] Loss:  0.048597 Accuracy:  1.0000
# [Training(152/-1)] Loss:  0.044898 Accuracy:  1.0000
# [Validation(152/-1)] Loss:  0.045976 Accuracy:  1.0000
# [Training(153/-1)] Loss:  0.049862 Accuracy:  1.0000
# [Validation(153/-1)] Loss:  0.045598 Accuracy:  1.0000
# [Training(154/-1)] Loss:  0.041498 Accuracy:  1.0000
# [Validation(154/-1)] Loss:  0.045584 Accuracy:  1.0000
# [Training(155/-1)] Loss:  0.104505 Accuracy:  1.0000
# [Validation(155/-1)] Loss:  0.038805 Accuracy:  1.0000
# [Training(156/-1)] Loss:  0.066860 Accuracy:  1.0000
# [Validation(156/-1)] Loss:  0.034072 Accuracy:  1.0000
# [Training(157/-1)] Loss:  0.077655 Accuracy:  1.0000
# [Validation(157/-1)] Loss:  0.031574 Accuracy:  1.0000
# [Training(158/-1)] Loss:  0.029509 Accuracy:  1.0000
# [Validation(158/-1)] Loss:  0.029299 Accuracy:  1.0000
# [Training(159/-1)] Loss:  0.040256 Accuracy:  1.0000
# [Validation(159/-1)] Loss:  0.026666 Accuracy:  1.0000
# [Training(160/-1)] Loss:  0.029731 Accuracy:  1.0000
# [Validation(160/-1)] Loss:  0.024596 Accuracy:  1.0000
# [Training(161/-1)] Loss:  0.028877 Accuracy:  1.0000
# [Validation(161/-1)] Loss:  0.022820 Accuracy:  1.0000
# [Training(162/-1)] Loss:  0.049907 Accuracy:  1.0000
# [Validation(162/-1)] Loss:  0.020766 Accuracy:  1.0000
# [Training(163/-1)] Loss:  0.023560 Accuracy:  1.0000
# [Validation(163/-1)] Loss:  0.019606 Accuracy:  1.0000
# [Training(164/-1)] Loss:  0.021669 Accuracy:  1.0000
# [Validation(164/-1)] Loss:  0.018735 Accuracy:  1.0000
# [Training(165/-1)] Loss:  0.021510 Accuracy:  1.0000
# [Validation(165/-1)] Loss:  0.017733 Accuracy:  1.0000
# [Training(166/-1)] Loss:  0.026354 Accuracy:  1.0000
# [Validation(166/-1)] Loss:  0.016515 Accuracy:  1.0000
# [Training(167/-1)] Loss:  0.022412 Accuracy:  1.0000
# [Validation(167/-1)] Loss:  0.014978 Accuracy:  1.0000
# [Training(168/-1)] Loss:  0.026878 Accuracy:  1.0000
# [Validation(168/-1)] Loss:  0.013217 Accuracy:  1.0000
# [Training(169/-1)] Loss:  0.013648 Accuracy:  1.0000
# [Validation(169/-1)] Loss:  0.011986 Accuracy:  1.0000
# [Training(170/-1)] Loss:  0.017073 Accuracy:  1.0000
# [Validation(170/-1)] Loss:  0.011196 Accuracy:  1.0000
# [Training(171/-1)] Loss:  0.167216 Accuracy:  0.9333
# [Validation(171/-1)] Loss:  0.015078 Accuracy:  1.0000
# [Training(172/-1)] Loss:  0.023068 Accuracy:  1.0000
# [Validation(172/-1)] Loss:  0.024157 Accuracy:  1.0000
# [Training(173/-1)] Loss:  0.026362 Accuracy:  1.0000
# [Validation(173/-1)] Loss:  0.033928 Accuracy:  1.0000
# [Training(174/-1)] Loss:  0.031106 Accuracy:  1.0000
# [Validation(174/-1)] Loss:  0.048413 Accuracy:  1.0000
# [Training(175/-1)] Loss:  0.055433 Accuracy:  1.0000
# [Validation(175/-1)] Loss:  0.053842 Accuracy:  1.0000
# [Training(176/-1)] Loss:  0.122411 Accuracy:  1.0000
# [Validation(176/-1)] Loss:  0.050485 Accuracy:  1.0000
# [Training(177/-1)] Loss:  0.056396 Accuracy:  1.0000
# [Validation(177/-1)] Loss:  0.048287 Accuracy:  1.0000
# [Training(178/-1)] Loss:  0.087395 Accuracy:  1.0000
# [Validation(178/-1)] Loss:  0.048235 Accuracy:  1.0000
# [Training(179/-1)] Loss:  0.047853 Accuracy:  1.0000
# [Validation(179/-1)] Loss:  0.050830 Accuracy:  1.0000
# [Training(180/-1)] Loss:  0.054437 Accuracy:  1.0000
# [Validation(180/-1)] Loss:  0.049751 Accuracy:  1.0000
# [Training(181/-1)] Loss:  0.058803 Accuracy:  1.0000
# [Validation(181/-1)] Loss:  0.037868 Accuracy:  1.0000
# [Training(182/-1)] Loss:  0.042282 Accuracy:  1.0000
# [Validation(182/-1)] Loss:  0.020607 Accuracy:  1.0000
# [Training(183/-1)] Loss:  0.023351 Accuracy:  1.0000
# [Validation(183/-1)] Loss:  0.012627 Accuracy:  1.0000
# [Training(184/-1)] Loss:  0.019711 Accuracy:  1.0000
# [Validation(184/-1)] Loss:  0.010032 Accuracy:  1.0000
# [Training(185/-1)] Loss:  0.011905 Accuracy:  1.0000
# [Validation(185/-1)] Loss:  0.009117 Accuracy:  1.0000
# [Training(186/-1)] Loss:  0.012906 Accuracy:  1.0000
# [Validation(186/-1)] Loss:  0.008596 Accuracy:  1.0000
# [Training(187/-1)] Loss:  0.014804 Accuracy:  1.0000
# [Validation(187/-1)] Loss:  0.008068 Accuracy:  1.0000
# [Training(188/-1)] Loss:  0.011921 Accuracy:  1.0000
# [Validation(188/-1)] Loss:  0.007547 Accuracy:  1.0000
# [Training(189/-1)] Loss:  0.011104 Accuracy:  1.0000
# [Validation(189/-1)] Loss:  0.006722 Accuracy:  1.0000
# [Training(190/-1)] Loss:  0.008643 Accuracy:  1.0000
# [Validation(190/-1)] Loss:  0.005830 Accuracy:  1.0000
# [Training(191/-1)] Loss:  0.005738 Accuracy:  1.0000
# [Validation(191/-1)] Loss:  0.005093 Accuracy:  1.0000
# [Training(192/-1)] Loss:  0.004851 Accuracy:  1.0000
# [Validation(192/-1)] Loss:  0.004485 Accuracy:  1.0000
# [Training(193/-1)] Loss:  0.005187 Accuracy:  1.0000
# [Validation(193/-1)] Loss:  0.004001 Accuracy:  1.0000
# [Training(194/-1)] Loss:  0.004734 Accuracy:  1.0000
# [Validation(194/-1)] Loss:  0.003585 Accuracy:  1.0000
# [Training(195/-1)] Loss:  0.004513 Accuracy:  1.0000
# [Validation(195/-1)] Loss:  0.003222 Accuracy:  1.0000
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmpjogmkmy0/model.weights

# %%
from atlas.models.utils import save_model
save_model(model, "./trained_model.zip")

# %% [markdown]
# ## Putting it All Together

# %% [markdown]
# Let's assign the model we just trained to our original generator

# %%
from atlas.models.utils import restore_model
model = restore_model("./trained_model.zip")
pivot_args_generator.set_default_model(model)
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmpka363tl9/models/pivot_args_generator/Select@@1/model.weights
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmpka363tl9/models/pivot_args_generator/Select@@2/model.weights
# INFO:tensorflow:Restoring parameters from /var/folders/s9/__w2d9dx2ljdx9qk865hh5qs559bh9/T/tmpka363tl9/models/pivot_args_generator/Select@@3/model.weights

# %% [markdown]
# Let's try running our trained generator on an unseen input-output example

# %%
unseen_input_df = pd.DataFrame({
    'series': {0: 'A', 1: 'B', 2: 'C', 3: 'A', 4: 'B', 5: 'C', 6: 'A', 7: 'B', 8: 'C', 9: 'A', 10: 'B', 11: 'C', 12: 'A', 13: 'B', 14: 'C'},
    'step': {0: '100', 1: '100', 2: '100', 3: '101', 4: '101', 5: '101', 6: '102', 7: '102', 8: '102', 9: '103', 10: '103', 11: '103', 12: '104', 13: '104', 14: '104'},
    'value': {0: '1000', 1: '1001', 2: '1002', 3: '1003', 4: '1004', 5: '1005', 6: '1006', 7: '1007', 8: '1008', 9: '1009', 10: '1010', 11: '1011', 12: '1012', 13: '1013', 14: '1014'}
})
unseen_input_df
# Out:
#    series step value
# 0       A  100  1000
# 1       B  100  1001
# 2       C  100  1002
# 3       A  101  1003
# 4       B  101  1004
# 5       C  101  1005
# 6       A  102  1006
# 7       B  102  1007
# 8       C  102  1008
# 9       A  103  1009
# 10      B  103  1010
# 11      C  103  1011
# 12      A  104  1012
# 13      B  104  1013
# 14      C  104  1014

# %%
unseen_output_df = pd.DataFrame({
    'A': {'100': '1000', '101': '1003', '102': '1006', '103': '1009', '104': '1012'},
    'B': {'100': '1001', '101': '1004', '102': '1007', '103': '1010', '104': '1013'},
    'C': {'100': '1002', '101': '1005', '102': '1008', '103': '1011', '104': '1014'}
})
unseen_output_df
# Out:
#         A     B     C
# 100  1000  1001  1002
# 101  1003  1004  1005
# 102  1006  1007  1008
# 103  1009  1010  1011
# 104  1012  1013  1014

# %%
synthesize(unseen_input_df, unseen_output_df)
# Out:
# Trying Combination: {'columns': 'series', 'index': 'step', 'values': None}
# Trying Combination: {'columns': 'series', 'index': 'step', 'values': 'value'}
# Solution Found: {'columns': 'series', 'index': 'step', 'values': 'value'}

# %% [markdown]
# Success! As you can see, our trained generator found the solution within the first few attempts! What is even more remarkable is that we trained it on a very small amount of data, data that looked very different from the training dataset.
